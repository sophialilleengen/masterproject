# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
from mpl_toolkits.mplot3d import Axes3D
import copy

from areposnap.gadget import gadget_readsnap
from areposnap.gadget_subfind import load_subfind

from auriga_basics import *

# %%
#### path = /hits/universe/GigaGalaxy/level4_MHD/halo_24/output/*
level = 4
basedir = "/hits/universe/GigaGalaxy/level4_MHD/"
j = 0
for halo_number in [24]:  # range(1, 31):
    halodir = basedir+"halo_{0}/".format(halo_number)
    snappath = halodir+"output/"
    for snapnr in range(127,128,1):
        print("level   : {0}".format(level))
        print("halo    : {0}".format(halo_number))
        print("snapnr  : {0}".format(snapnr))
        print("basedir : {0}".format(basedir))
        print("halodir : {0}".format(halodir))
        print("snappath: {0}\n".format(snappath))
        s, sf = eat_snap_and_fof(level, halo_number, snapnr, snappath, loadonlytype=[0,1,2,3,4,5], 
            haloid=0, galradfac=0.1, verbose=True) 

        # Clean negative and zero values of gmet to avoid RuntimeErrors
        # later on (e.g. dividing by zero)
        s.data['gmet'] = np.maximum( s.data['gmet'], 1e-40 )
# Out:
# level   : 4
# halo    : 24
# snapnr  : 127
# basedir : /hits/universe/GigaGalaxy/level4_MHD/
# halodir : /hits/universe/GigaGalaxy/level4_MHD/halo_24/
# snappath: /hits/universe/GigaGalaxy/level4_MHD/halo_24/output/
#
# [ 34.42281723  33.16259384  37.29567337]
# Found 1783163 stars.
# Rotated pos.
# Rotated bfld.
# Rotated vel.
#
# galrad  : 0.02408556640148163
# redshift: 2.220446049250313e-16
# time    : 0.9999999999999998
# center  : [ 0.  0.  0.]

# %%
istars, = np.where( (s.type == 4) & (s.halo == 0) )#& (s.subhalo == 0))
(x, y, z), (vx, vy, vz), rxyz, rxy = get_cartesian_vectors(s, sf, istars)

binnum = 401
H1, xedges1, yedges1 = np.histogram2d(x, y, bins=binnum)
H2, xedges2, yedges2 = np.histogram2d(rxy, z, bins=binnum)
vmin = 1e0
if np.max(H1) > np.max(H2):
    vmax = np.max(H1)
else: vmax = np.max(H2)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))
h1 = ax1.hist2d(1000*x, 1000*y, bins=binnum, norm=matplotlib.colors.LogNorm(), cmap = 'inferno', vmin = vmin, vmax = vmax)
h2 = ax2.hist2d(1000*rxy, 1000*z, bins=binnum, norm=matplotlib.colors.LogNorm(), cmap = 'inferno', vmin = vmin, vmax= vmax)
ax1.set_xlabel("x [kpc]")
ax1.set_ylabel("y [kpc]")
ax1.set_aspect('equal')
ax2.set_xlabel("R [kpc]")
ax2.set_ylabel("z [kpc]")
ax2.set_aspect('equal')
cbar2 = fig.colorbar(h2[3], ax = ax2 )

# %%
istars, = np.where( (s.type == 4) & (s.halo == 0) )#& (s.subhalo == 0))
(x, y, z), (vx, vy, vz), rxyz, rxy = get_cartesian_vectors(s, sf, istars)

binnumxx = 401
cmap = copy.copy(plt.cm.inferno)
cmap.set_bad((0,0,0))  # Fill background with black

fig, ax = plt.subplots(1, 1, figsize=(12, 12))
h = ax.hist2d(1000*x, 1000*y, bins=binnumxx, norm=matplotlib.colors.LogNorm(), cmap = cmap, \
           range = [[-400,400], [-400, 400]])
ax.set_xlabel("x [kpc]")
ax.set_ylabel("y [kpc]")
ax.set_aspect('equal')
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.2)
fig.colorbar(h[3], cax=cax)
#fig.savefig('aur_24_xy_distribution.png', dpi = 300, format = 'png', bbox_inches = 'tight')

# %%
## density
istars, = np.where( (s.type == 4) & (s.halo == 0) & (s.r() > 0.) & (s.r() < s.galrad) )
(R, phi, z), (vR, vphi, vz) = get_cylindrical_vectors(s, sf, istars)

# %%
def dens(M, R, z, dR, dz):
    
    Rmin, Rmax = np.min(R), np.max(R)
    if Rmin == 0.:
        Rmin = np.sort(R)[1]
    zmin, zmax = np.abs(np.min(np.abs(z))), np.abs(np.max(np.abs(z)))
    if zmin == 0.:
        zmin = np.abs(np.sort(z)[1])    
    print('Rmin:', Rmin, 'Rmax:', Rmax, 'dR:', dR)
    print('zmin:', zmin, 'zmax:', zmax, 'dz:', dz)
    Rbins, zbins = np.arange(Rmin, Rmax, dR), np.arange(zmin, zmax, dz)
    mbins, volbins = np.zeros((len(Rbins), len(zbins))), np.zeros((len(Rbins), len(zbins)))
    for i in range(len(Rbins)):
        for j in range(len(zbins)):
            if i == 0:
                if j == 0:
                    inbin = (0. <= R) & (R < Rbins[i+1]) & (0. <= np.abs(z)) & (np.abs(z) < zbins[j+1])
                    mbins[i,j] = np.sum(M[inbin])
                    volbins[i,j] = np.pi * dz * (dR**2)    
                elif j < len(zbins) - 1:
                    inbin = (0 <= R) & (R < Rbins[i+1]) & (zbins[j] <= np.abs(z)) & (np.abs(z) < zbins[j+1])
                    mbins[i,j] = np.sum(M[inbin])
                    volbins[i,j] = np.pi * dz * (2. * Rbins[i] * dR - dR**2)
                elif j == len(zbins) - 1:
                    inbin = (0 <= R) & (R < Rbins[i+1]) & (zbins[j] <= np.abs(z)) & (np.abs(z) < (zbins[j] + dz))
                    mbins[i,j] = np.sum(M[inbin])
                    volbins[i,j] = np.pi * dz * (2. * Rbins[i] * dR - dR**2)
                else:
                    print(len(zbins), j)                    
            elif i < len(Rbins) - 1:
                if j == 0:
                    inbin = (Rbins[i] <= R) & (R < Rbins[i+1]) & (0. <= np.abs(z)) & (np.abs(z) < zbins[j+1])
                    mbins[i,j] = np.sum(M[inbin])
                    volbins[i,j] = np.pi * dz * (2. * Rbins[i] * dR - dR**2)
                elif j < len(zbins) - 1:
                    inbin = (Rbins[i] <= R) & (R < Rbins[i+1]) & (zbins[j] <= np.abs(z)) & (np.abs(z) < zbins[j+1])
                    mbins[i,j] = np.sum(M[inbin])
                    volbins[i,j] = np.pi * dz * (2. * Rbins[i] * dR - dR**2)
                elif j == len(zbins) - 1:
                    inbin = (Rbins[i] <= R) & (R < Rbins[i+1]) & (zbins[j] <= np.abs(z)) & (np.abs(z) < (zbins[j] + dz))
                    mbins[i,j] = np.sum(M[inbin])
                    volbins[i,j] = np.pi * dz * (2. * Rbins[i] * dR - dR**2)
                else:
                    print(len(zbins), j)
            elif i == len(Rbins) - 1:
                if j == 0:
                    inbin = (Rbins[i] <= R) & (R < (Rbins[i] + dR)) & (0. <= np.abs(z)) & (np.abs(z) < zbins[j+1])
                    mbins[i,j] = np.sum(M[inbin])
                    volbins[i,j] = np.pi * dz * (2. * Rbins[i] * dR - dR**2)
                elif j < len(zbins) - 1:
                    inbin = (Rbins[i] <= R) & (R < (Rbins[i] + dR)) & (zbins[j] <= np.abs(z)) & (np.abs(z) < zbins[j+1])
                    mbins[i,j] = np.sum(M[inbin])
                    volbins[i,j] = np.pi * dz * (2. * Rbins[i] * dR - dR**2)
                elif j == len(zbins) - 1:
                    inbin = (Rbins[i] <= R) & (R < (Rbins[i] + dR)) & (zbins[j] <= np.abs(z)) & (np.abs(z) < (zbins[j] + dz))
                    mbins[i,j] = np.sum(M[inbin])
                    volbins[i,j] = np.pi * dz * (2. * Rbins[i] * dR - dR**2)
                else:
                    print(len(zbins), j, len(Rbins), i)
            else:
                print(len(Rbins), i)
             
            
    
    #vol = np.pi * dz * (2. * R * dR - dR**2)
    #mass = M 

    rho = mbins/volbins
    #print(rho)
    return(rho, Rbins, zbins)

# %%
rho, Rbins, zbins = dens(s.mass[istars], R, z, 0.5e-3, 0.5e-3)
# Out:
# Rmin: 5.91963e-07 Rmax: 0.0240853 dR: 0.0005
# zmin: 1.45519e-10 zmax: 0.0239306 dz: 0.0005

# %%
Rarr = np.repeat(Rbins, len(zbins))
zarr = np.tile(zbins, len(Rbins))
rhoarr = np.ravel(rho)
print(len(Rarr), len(zarr), len(rhoarr))
# Out:
# 2352 2352 2352

# %%
plt.semilogy(Rarr, rhoarr, '.')
plt.semilogy(zarr, rhoarr, '.')
#plt.plot(zbins, rho[:, 1])

# %%
rho_test = np.log10(rhoarr)
# Out:
# /home/extmilan/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log10
#   """Entry point for launching an IPython kernel.
# /home/extmilan/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in log10
#   """Entry point for launching an IPython kernel.

# %%
fig = plt.figure(figsize=(12,12))
ax = fig.add_subplot(111, projection='3d')
ax.plot(Rarr, zarr, rho_test, '.')
ax.set_xlabel('R [Mpc]')
ax.set_ylabel('z [Mpc]')
ax.set_zlabel('log10(rho)')

ax.view_init(30, 45)

#ax.set_zscale('log')
# Out:
# /home/extmilan/anaconda3/lib/python3.6/site-packages/mpl_toolkits/mplot3d/proj3d.py:141: RuntimeWarning: invalid value encountered in true_divide
#   txs, tys, tzs = vecw[0]/w, vecw[1]/w, vecw[2]/w
