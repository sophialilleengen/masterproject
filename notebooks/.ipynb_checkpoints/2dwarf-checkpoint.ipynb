# %%
machine = 'mac'
machine = 'magny'

# %%
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
from mpl_toolkits.mplot3d import Axes3D
import copy

from areposnap.gadget import gadget_readsnap
from areposnap.gadget_subfind import load_subfind

from auriga_basics import *
from auriga_functions import *
# %matplotlib inline

# %%
#### path = /hits/universe/GigaGalaxy/level4_MHD/halo_24/output/*
level = 4
if machine == 'magny':
    basedir = "/hits/universe/GigaGalaxy/level4_MHD/"
elif machine == 'mac': 
    basedir = "/Users/smilanov/Desktop/Auriga/level4/"
j = 0
for halo_number in [24]:  # range(1, 31):
    halodir = basedir+"halo_{0}/".format(halo_number)
    snappath = halodir+"output/"
    '''
    s_main, sf_main =  eat_snap_and_fof(level, halo_number, 127, snappath, loadonlytype=[4], 
            haloid=0, galradfac=0.1, verbose=True) 
    s_main.data['gmet'] = np.maximum( s_main.data['gmet'], 1e-40 )
    istars, = np.where( (s.type == 4) & (s.halo == 0) )
    (x_main_Mpc, y_main_Mpc, z_main_Mpc), (vx_main_Mpc, vy_main_Mpc, vz_main_Mpc), rxyz_main_Mpc, rxy_main_Mpc = get_cartesian_vectors(s, sf, istars)
    '''
    for snapnr in [127]:
        print("level   : {0}".format(level))
        print("halo    : {0}".format(halo_number))
        print("snapnr  : {0}".format(snapnr))
        print("basedir : {0}".format(basedir))
        print("halodir : {0}".format(halodir))
        print("snappath: {0}\n".format(snappath))
        s, sf = eat_snap_and_fof(level, halo_number, snapnr, snappath, loadonlytype=[4], 
            haloid=0, galradfac=0.1, verbose=True) 

        # Clean negative and zero values of gmet to avoid RuntimeErrors
        # later on (e.g. dividing by zero)
        s.data['gmet'] = np.maximum( s.data['gmet'], 1e-40 )
# Out:
# level   : 4
# halo    : 24
# snapnr  : 127
# basedir : /hits/universe/GigaGalaxy/level4_MHD/
# halodir : /hits/universe/GigaGalaxy/level4_MHD/halo_24/
# snappath: /hits/universe/GigaGalaxy/level4_MHD/halo_24/output/
#
# [ 34.42281723  33.16259384  37.29567337]
# Found 1783163 stars.
# Rotated pos.
# Rotated vel.
#
# galrad  : 0.02408556640148163
# redshift: 2.220446049250313e-16
# time    : 0.9999999999999998
# center  : [ 0.  0.  0.]

# %%
def dwarf_selection(s, sf, z_kpc_val, level, halo_number, snapnr, snappath, subhalonr, partnr, verbose = True, outplot = True, outfile = False):
    '''
    NAME: 
        dwarf_selection
    INPUT:
        s, sf: z=0 snapshot
        z_kpc: absolute disk height in kpc
        level, halo_number, snapnr, snappath: snapshot in which dwarf is selected (INT; 0 < snapnr < 127)
        subhalonr: which subhalo should be selected (INT; 0 < subhalonr)
        partnr: number of random selected dwarf particles (INT)
        outplot: if True, plots marked dwarf in early and z=0 snapshot; default = True
        outfile: if True, saves information on dwarfs in file; default = False
    HISTORY:
        02-02-2018: written (Milanov, ESO)
    '''
    # read in early snapshot
    try:
        es, esf = eat_snap_and_fof(level, halo_number, snapnr, snappath, loadonlytype=[4], 
                haloid=0, galradfac=0.1, verbose=False)   
    except KeyError:
        return
    except IndexError:
        return
    es.data['gmet'] = np.maximum( es.data['gmet'], 1e-40 )
    
    
    if isinstance(subhalonr, list):
        outstr = ''

        for item in subhalonr:
            istarssub, = np.where( (es.type == 4) & (es.halo == 0) & (es.subhalo == item) )
            try:
                istarssubsample = np.random.choice(istarssub, partnr)
            except ValueError:
                break
            #istarssubsample = np.where( (es.type == 4) & (es.halo == 0) & (es.subhalo == 1) & (1000. * np.abs(es.pos[::,0]) > z_kpc))
            ids_halo1 = es.id[istarssubsample]
            ids_halo1 = es.id[istarssub]



            istars, = np.where( (s.type == 4) & (s.halo == 0) )
            (x_kpc, y_kpc, z_kpc), (vx_kpc, vy_kpc, vz_kpc), rxyz_kpc, rxy_kpc = get_cartesian_vectors(s, sf, istars)
            istarse, = np.where( (es.type == 4) & (es.halo == 0) )
            (ex_kpc, ey_kpc, ez_kpc), (evx_kpc, evy_kpc, evz_kpc), erxyz_kpc, erxy_kpc = get_cartesian_vectors(es, esf, istarse)

            subhalomask = np.isin(s.id[istars], ids_halo1)
            esubhalomask = np.isin(es.id[istarse], ids_halo1)
            z_sample = np.where((np.abs(z_kpc) > z_kpc_val) & (rxyz_kpc < 5. * 1000. * s.galrad), True, False)


            survivors = np.sum(z_sample * subhalomask)
            starters = np.sum(esubhalomask)
            frac = round(survivors/starters, 3)
            outstr += '\tSH:' + str(item) + '\t' + str(frac) + '\t' + str(survivors) + '\t' + str(starters)

            if verbose == True:
                print('Snapshot number:', snapnr,'\nfraction:', survivors , starters, frac, '\n')
            if outplot == True:
                fig, axes = plt.subplots(2, 2, figsize=(12, 12))     
                axes[0, 0].set_title(str(snapnr))
                axes[0, 0].hist2d(ex_kpc, ey_kpc, bins=401, norm=matplotlib.colors.LogNorm(), cmap = 'Greys')
                axes[0, 0].plot(ex_kpc[esubhalomask], ey_kpc[esubhalomask], 'r.', alpha = 0.3)
                axes[0, 0].set_xlabel("x")
                axes[0, 0].set_ylabel("y")
                axes[0, 0].set_aspect('equal')
                axes[0, 1].hist2d(erxy_kpc, ez_kpc, bins=401, norm=matplotlib.colors.LogNorm(), cmap = 'Greys')
                axes[0, 1].plot(erxy_kpc[esubhalomask], ez_kpc[esubhalomask], 'r.', alpha = 0.3)
                axes[0, 1].set_xlabel("R")
                axes[0, 1].set_ylabel("z")
                axes[0, 1].set_aspect('equal')

                axes[1, 0].hist2d(x_kpc, y_kpc, bins=401, norm=matplotlib.colors.LogNorm(), cmap = 'Greys')
                axes[1, 0].plot(x_kpc[z_sample * subhalomask], y_kpc[z_sample * subhalomask], 'r.', alpha = 0.3)
                axes[1, 0].set_xlabel("x")
                axes[1, 0].set_ylabel("y")
                axes[1, 0].set_aspect('equal')
                axes[1, 1].hist2d(rxy_kpc, z_kpc, bins=401, norm=matplotlib.colors.LogNorm(), cmap = 'Greys')
                axes[1, 1].plot(rxy_kpc[z_sample * subhalomask], z_kpc[z_sample * subhalomask], 'r.', alpha = 0.3)
                axes[1, 1].set_xlabel("R")
                axes[1, 1].set_ylabel("z")
                axes[1, 1].set_aspect('equal')
                #fig.show()
        
        snap_time = s.cosmology_get_lookback_time_from_a( es.time, is_flat=True )
        snap_redshift = es.redshift
        #survivor_age = star_age[z_sample * subhalomask]
        if outfile == True:
            with open('/home/extmilan/masterthesis/files/test2.txt','a') as f:
                f.write(str(snapnr) + '\t' + str(snap_time) + '\t' + str(snap_redshift) + outstr + '\n')
   

    else:
        istarssub, = np.where( (es.type == 4) & (es.halo == 0) & (es.subhalo == subhalonr) )
        istarssubsample = np.random.choice(istarssub, partnr)
        #istarssubsample = np.where( (es.type == 4) & (es.halo == 0) & (es.subhalo == 1) & (1000. * np.abs(es.pos[::,0]) > z_kpc))
        ids_halo1 = es.id[istarssubsample]
        ids_halo1 = es.id[istarssub]



        istars, = np.where( (s.type == 4) & (s.halo == 0) )
        (x_kpc, y_kpc, z_kpc), (vx_kpc, vy_kpc, vz_kpc), rxyz_kpc, rxy_kpc = get_cartesian_vectors(s, sf, istars)
        istarse, = np.where( (es.type == 4) & (es.halo == 0) )
        (ex_kpc, ey_kpc, ez_kpc), (evx_kpc, evy_kpc, evz_kpc), erxyz_kpc, erxy_kpc = get_cartesian_vectors(es, esf, istarse)

        subhalomask = np.isin(s.id[istars], ids_halo1)
        esubhalomask = np.isin(es.id[istarse], ids_halo1)
        z_sample = np.where((np.abs(z_kpc) > z_kpc_val) & (rxyz_kpc < 5. * 1000. * s.galrad), True, False)


        survivors = np.sum(z_sample * subhalomask)
        starters = np.sum(esubhalomask)
        frac = round(survivors/starters, 3)

        snap_time = s.cosmology_get_lookback_time_from_a( es.time, is_flat=True )
        snap_redshift = es.redshift
        #survivor_age = star_age[z_sample * subhalomask]


        if verbose == True:
            print('Snapshot number:', snapnr,'\nfraction:', survivors , starters, frac, '\n')
        if outplot == True:
            fig, axes = plt.subplots(2, 2, figsize=(12, 12))     
            axes[0, 0].set_title(str(snapnr))
            axes[0, 0].hist2d(ex_kpc, ey_kpc, bins=401, norm=matplotlib.colors.LogNorm(), cmap = 'Greys')
            axes[0, 0].plot(ex_kpc[esubhalomask], ey_kpc[esubhalomask], 'r.', alpha = 0.3)
            axes[0, 0].set_xlabel("x")
            axes[0, 0].set_ylabel("y")
            axes[0, 0].set_aspect('equal')
            axes[0, 1].hist2d(erxy_kpc, ez_kpc, bins=401, norm=matplotlib.colors.LogNorm(), cmap = 'Greys')
            axes[0, 1].plot(erxy_kpc[esubhalomask], ez_kpc[esubhalomask], 'r.', alpha = 0.3)
            axes[0, 1].set_xlabel("R")
            axes[0, 1].set_ylabel("z")
            axes[0, 1].set_aspect('equal')

            axes[1, 0].hist2d(x_kpc, y_kpc, bins=401, norm=matplotlib.colors.LogNorm(), cmap = 'Greys')
            axes[1, 0].plot(x_kpc[z_sample * subhalomask], y_kpc[z_sample * subhalomask], 'r.', alpha = 0.3)
            axes[1, 0].set_xlabel("x")
            axes[1, 0].set_ylabel("y")
            axes[1, 0].set_aspect('equal')
            axes[1, 1].hist2d(rxy_kpc, z_kpc, bins=401, norm=matplotlib.colors.LogNorm(), cmap = 'Greys')
            axes[1, 1].plot(rxy_kpc[z_sample * subhalomask], z_kpc[z_sample * subhalomask], 'r.', alpha = 0.3)
            axes[1, 1].set_xlabel("R")
            axes[1, 1].set_ylabel("z")
            axes[1, 1].set_aspect('equal')
            #fig.show()


        if outfile == True:
            with open('/home/extmilan/masterthesis/files/test.txt','a') as f:
                f.write(str(snapnr) + '\t' + str(snap_time) +  '\t' + str(snap_redshift) + '\t' + str(frac) + '\t' + str(survivors) + '\t' + str(starters) + '\n')

# %%
halo_number = 24
halodir = basedir+"halo_{0}/".format(halo_number)
snappath = halodir+"output/"
z_disk_kpc = 1.5

first_comm = 'Halo ' + str(halo_number) + '; disk_height: ' + str(z_disk_kpc) +\
'\nSnapnr; Age; Redshift; Subhalo number; surviving fraction; number of survivors; number of dwarf particles (can be repeated)\n'
with open('/home/extmilan/masterthesis/files/test2.txt','a') as f:
    f.write(first_comm)
for i in range(0,128,1):
    dwarf_selection(s, sf, z_disk_kpc, level, halo_number, i, snappath, [1,2,3], 50, outfile = True, outplot= False)
# Out:
# [ 0.68997848  0.73377794  0.72552913]
# ../../anaconda3/lib/python3.6/site-packages/areposnap/gadget_snap.py:1515: RuntimeWarning: invalid value encountered in true_divide
#   vel = (self.vel[iall,:] * mass[iall][:,None]).sum(axis=0) / mass[iall].sum()
# [ 0.7234897   0.76935881  0.76080716]
# [ 0.768911    0.81777596  0.78662628]
# [ 0.80237359  0.85338241  0.82094795]
# Found 0 stars.
# ../../anaconda3/lib/python3.6/site-packages/areposnap/gadget_snap.py:1545: RuntimeWarning: invalid value encountered in true_divide
#   Ldir = Ltot / sqrt( (Ltot**2).sum() )
# [ 0.82093781  0.76843476  0.86288393]
# Found 0 stars.
# [ 0.86797398  0.79862845  0.87235445]
# Found 0 stars.
# [ 0.990309    0.81678659  0.9078902 ]
# Found 0 stars.
# [ 1.00251687  0.93924028  1.00887811]
# Found 0 stars.
# [ 1.05116498  0.98489976  1.05819023]
# Found 0 stars.
# [ 1.10215628  1.03271687  1.10996389]
# Found 0 stars.
# [ 1.155689    1.08288169  1.16423106]
# Found 0 stars.
# [ 1.21178746  1.13550091  1.22114444]
# Found 0 stars.
# [ 1.26454604  1.18501997  1.27483451]
# Found 0 stars.
# [ 1.32594752  1.24260163  1.33726978]
# Found 0 stars.
# [ 1.39032078  1.30296481  1.40279269]
# Found 0 stars.
# [ 1.45787263  1.36626518  1.47153223]
# Found 0 stars.
# [ 1.52146435  1.42590559  1.53629541]
# Found 0 stars.
# [ 1.56192708  1.51133966  1.48895395]
# Found 0 stars.
# [ 1.63803804  1.58520019  1.56137872]
# Found 0 stars.
# [ 1.71728933  1.66236067  1.63795924]
# Found 0 stars.
# [ 1.79199338  1.73505008  1.710145  ]
# Found 0 stars.
# [ 1.87885857  1.81956458  1.79405308]
# Found 0 stars.
# [ 1.96997511  1.90820003  1.88173497]
# Found 0 stars.
# [ 2.06547499  2.0011797   1.97422838]
# Found 1 stars.
# [ 2.15539694  2.08879709  2.06132317]
# Found 0 stars.
# [ 2.25987601  2.19063401  2.16238689]
# Found 0 stars.
# [ 2.3694756   2.29740047  2.2686007 ]
# Found 4 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 26
# fraction: 0 8 0.0
#
# [ 2.48446131  2.40939927  2.38007212]
# Found 2 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 27
# fraction: 0 10 0.0
#
# Snapshot number: 27
# fraction: 0 1 0.0
#
# Snapshot number: 27
# fraction: 0 3 0.0
#
# [ 2.60516763  2.52686286  2.49723887]
# Found 1 stars.
# [ 2.71875334  2.63748837  2.60741425]
# Found 6 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 29
# fraction: 3 17 0.176
#
# Snapshot number: 29
# fraction: 0 7 0.0
#
# [ 2.83273578  2.61936808  2.86838841]
# Found 3 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 30
# fraction: 0 26 0.0
#
# Snapshot number: 30
# fraction: 0 8 0.0
#
# Snapshot number: 30
# fraction: 0 5 0.0
#
# [ 2.96990299  2.74538374  3.00988245]
# Found 3 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 31
# fraction: 0 114 0.0
#
# Snapshot number: 31
# fraction: 0 10 0.0
#
# Snapshot number: 31
# fraction: 0 17 0.0
#
# [ 3.18649602  2.90000153  3.03076434]
# Found 41 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 32
# fraction: 0 15 0.0
#
# Snapshot number: 32
# fraction: 2 23 0.087
#
# [ 3.24688745  2.99542761  3.30316663]
# Found 9 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 33
# fraction: 0 187 0.0
#
# Snapshot number: 33
# fraction: 0 89 0.0
#
# Snapshot number: 33
# fraction: 0 9 0.0
#
# [ 3.48630524  3.1776216   3.32057261]
# Found 66 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 34
# fraction: 0 6 0.0
#
# [ 3.57852936  3.41344523  3.59672785]
# Found 77 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 35
# fraction: 14 87 0.161
#
# [ 3.88295197  3.44158649  3.88973498]
# Found 100 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 36
# fraction: 0 48 0.0
#
# Snapshot number: 36
# fraction: 0 12 0.0
#
# Snapshot number: 36
# fraction: 0 38 0.0
#
# [ 3.94040155  3.67384386  3.99745083]
# Found 161 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 37
# fraction: 0 258 0.0
#
# Snapshot number: 37
# fraction: 0 37 0.0
#
# Snapshot number: 37
# fraction: 0 21 0.0
#
# [ 4.2451396   3.77268314  4.26102448]
# Found 290 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 38
# fraction: 0 13 0.0
#
# Snapshot number: 38
# fraction: 0 28 0.0
#
# [ 4.26593399  4.15669727  4.23909092]
# Found 266 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 39
# fraction: 92 346 0.266
#
# Snapshot number: 39
# fraction: 3 23 0.13
#
# Snapshot number: 39
# fraction: 0 2 0.0
#
# [ 4.4739275   4.36128616  4.45105314]
# Found 420 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 40
# fraction: 86 200 0.43
#
# Snapshot number: 40
# fraction: 0 9 0.0
#
# Snapshot number: 40
# fraction: 0 6 0.0
#
# [ 4.76203728  4.62393808  4.62059116]
# Found 141 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 41
# fraction: 261 893 0.292
#
# Snapshot number: 41
# fraction: 247 846 0.292
#
# Snapshot number: 41
# fraction: 7 18 0.389
#
# [ 4.96745539  4.70612574  4.95621538]
# Found 305 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 42
# fraction: 119 815 0.146
#
# Snapshot number: 42
# fraction: 78 608 0.128
#
# Snapshot number: 42
# fraction: 14 109 0.128
#
# [ 5.20717669  4.93739939  5.20081854]
# Found 282 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 43
# fraction: 130 769 0.169
#
# Snapshot number: 43
# fraction: 52 392 0.133
#
# Snapshot number: 43
# fraction: 80 471 0.17
#
# [ 5.45930004  5.18125677  5.45793629]
# Found 565 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 44
# fraction: 57 361 0.158
#
# Snapshot number: 44
# fraction: 132 559 0.236
#
# Snapshot number: 44
# fraction: 80 412 0.194
#
# [ 5.73010778  5.57186985  5.58295202]
# Found 2910 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 45
# fraction: 531 2481 0.214
#
# Snapshot number: 45
# fraction: 0 4 0.0
#
# Snapshot number: 45
# fraction: 16 20 0.8
#
# [ 6.00896454  5.84421682  5.86421728]
# Found 2192 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 46
# fraction: 715 2077 0.344
#
# Snapshot number: 46
# fraction: 23 26 0.885
#
# Snapshot number: 46
# fraction: 35 44 0.795
#
# [ 6.27321196  6.0990777   6.13107109]
# Found 2811 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 47
# fraction: 680 1072 0.634
#
# Snapshot number: 47
# fraction: 22 26 0.846
#
# [ 6.56175327  6.25628424  6.60190868]
# Found 4498 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 48
# fraction: 1139 5954 0.191
#
# Snapshot number: 48
# fraction: 55 483 0.114
#
# Snapshot number: 48
# fraction: 16 222 0.072
#
# [ 6.87784338  6.56649303  6.93449736]
# Found 4934 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 49
# fraction: 1412 4307 0.328
#
# Snapshot number: 49
# fraction: 531 4181 0.127
#
# Snapshot number: 49
# fraction: 378 807 0.468
#
# [ 7.21020699  6.89154625  7.28530788]
# Found 6825 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 50
# fraction: 1533 4843 0.317
#
# Snapshot number: 50
# fraction: 831 2704 0.307
#
# Snapshot number: 50
# fraction: 374 476 0.786
#
# [ 7.55916452  7.23123264  7.65299654]
# Found 9271 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 51
# fraction: 1797 5102 0.352
#
# Snapshot number: 51
# fraction: 1058 1849 0.572
#
# Snapshot number: 51
# fraction: 396 515 0.769
#
# [ 7.92679119  7.58518696  8.0392313 ]
# Found 11260 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 52
# fraction: 543 2922 0.186
#
# Snapshot number: 52
# fraction: 1136 3234 0.351
#
# Snapshot number: 52
# fraction: 932 1480 0.63
#
# [ 8.3158474   7.95750761  8.43717575]
# Found 24087 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 53
# fraction: 602 1652 0.364
#
# Snapshot number: 53
# fraction: 850 2908 0.292
#
# Snapshot number: 53
# fraction: 7 81 0.086
#
# [ 8.7214613   8.35234547  8.85930157]
# Found 33710 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 54
# fraction: 434 2121 0.205
#
# Snapshot number: 54
# fraction: 570 684 0.833
#
# Snapshot number: 54
# fraction: 19 84 0.226
#
# [ 9.10364056  8.72417164  9.26056767]
# Found 34349 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 55
# fraction: 535 1789 0.299
#
# Snapshot number: 55
# fraction: 482 1415 0.341
#
# Snapshot number: 55
# fraction: 67 211 0.318
#
# [ 9.50209332  9.11564541  9.67981148]
# Found 41264 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 56
# fraction: 2469 7380 0.335
#
# Snapshot number: 56
# fraction: 952 1421 0.67
#
# Snapshot number: 56
# fraction: 541 1540 0.351
#
# [  9.87182808   9.4778223   10.06595612]
# Found 46848 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 57
# fraction: 18073 30114 0.6
#
# Snapshot number: 57
# fraction: 2868 7184 0.399
#
# Snapshot number: 57
# fraction: 1216 1584 0.768
#
# [ 10.25568104   9.85312176  10.46530151]
# Found 55529 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 58
# fraction: 19703 31518 0.625
#
# Snapshot number: 58
# fraction: 4233 8441 0.501
#
# Snapshot number: 58
# fraction: 737 1113 0.662
#
# [ 10.60555553  10.19394493  10.82572174]
# Found 68232 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 59
# fraction: 21506 33300 0.646
#
# Snapshot number: 59
# fraction: 4944 7532 0.656
#
# Snapshot number: 59
# fraction: 73 319 0.229
#
# [ 10.96751499  10.54684067  11.19934082]
# Found 84249 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 60
# fraction: 23403 34851 0.672
#
# Snapshot number: 60
# fraction: 4916 11079 0.444
#
# Snapshot number: 60
# fraction: 5682 8029 0.708
#
# [ 11.33949471  10.91451645  11.58535576]
# Found 103761 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 61
# fraction: 5606 13174 0.426
#
# Snapshot number: 61
# fraction: 20460 29535 0.693
#
# Snapshot number: 61
# fraction: 2208 5756 0.384
#
# [ 11.72626972  11.2924757   11.99002552]
# Found 156728 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 62
# fraction: 6472 15475 0.418
#
# Snapshot number: 62
# fraction: 2392 5671 0.422
#
# Snapshot number: 62
# fraction: 20944 30705 0.682
#
# [ 12.06752777  11.62145424  12.35484123]
# Found 164288 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 63
# fraction: 7214 13542 0.533
#
# Snapshot number: 63
# fraction: 2438 6933 0.352
#
# Snapshot number: 63
# fraction: 2607 6526 0.399
#
# [ 12.42007446  11.95782089  12.73314667]
# Found 226624 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 64
# fraction: 7849 12133 0.647
#
# Snapshot number: 64
# fraction: 2605 6292 0.414
#
# Snapshot number: 64
# fraction: 2807 5325 0.527
#
# [ 12.78022385  12.30894375  13.11660862]
# Found 284600 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 65
# fraction: 6327 10640 0.595
#
# Snapshot number: 65
# fraction: 8499 12190 0.697
#
# Snapshot number: 65
# fraction: 2901 7487 0.387
#
# [ 13.08854771  12.60904121  13.44554806]
# Found 351151 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 66
# fraction: 6811 9773 0.697
#
# Snapshot number: 66
# fraction: 3228 6149 0.525
#
# Snapshot number: 66
# fraction: 3307 5696 0.581
#
# [ 13.4669323   12.98056126  13.84910297]
# Found 371337 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 67
# fraction: 36328 49161 0.739
#
# Snapshot number: 67
# fraction: 9600 12919 0.743
#
# Snapshot number: 67
# fraction: 7823 9608 0.814
#
# [ 13.78952217  13.29696274  14.19396877]
# Found 415479 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 68
# fraction: 37704 51605 0.731
#
# Snapshot number: 68
# fraction: 10368 14684 0.706
#
# Snapshot number: 68
# fraction: 8132 8865 0.917
#
# [ 14.12320042  13.61969185  14.55005264]
# Found 458329 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 69
# fraction: 39657 54375 0.729
#
# Snapshot number: 69
# fraction: 10860 15103 0.719
#
# Snapshot number: 69
# fraction: 8985 10277 0.874
#
# [ 14.46787739  13.95026779  14.91678429]
# Found 483558 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 70
# fraction: 42542 58782 0.724
#
# Snapshot number: 70
# fraction: 10912 14502 0.752
#
# Snapshot number: 70
# fraction: 9298 10577 0.879
#
# [ 14.82138062  14.29028893  15.29212379]
# Found 513965 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 71
# fraction: 46115 65869 0.7
#
# Snapshot number: 71
# fraction: 16118 34133 0.472
#
# Snapshot number: 71
# fraction: 10961 15561 0.704
#
# [ 15.1824646   14.63997269  15.67546272]
# Found 536367 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 72
# fraction: 49472 62557 0.791
#
# Snapshot number: 72
# fraction: 17157 32173 0.533
#
# Snapshot number: 72
# fraction: 11347 17175 0.661
#
# [ 15.47813797  14.92653275  15.98590374]
# Found 667800 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 73
# fraction: 17931 33901 0.529
#
# Snapshot number: 73
# fraction: 11465 16351 0.701
#
# Snapshot number: 73
# fraction: 9649 11371 0.849
#
# [ 15.85394859  15.28774834  16.39402962]
# Found 754347 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 74
# fraction: 20833 42841 0.486
#
# Snapshot number: 74
# fraction: 11444 16459 0.695
#
# Snapshot number: 74
# fraction: 9783 11951 0.819
#
# [ 16.16160011  15.58262157  16.72860718]
# Found 788548 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 75
# fraction: 22983 39831 0.577
#
# Snapshot number: 75
# fraction: 11001 15184 0.725
#
# Snapshot number: 75
# fraction: 9782 11784 0.83
#
# [ 16.47659492  15.88422775  17.06827354]
# Found 817842 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 76
# fraction: 23157 40289 0.575
#
# Snapshot number: 76
# fraction: 9739 11876 0.82
#
# Snapshot number: 76
# fraction: 9112 11856 0.769
#
# [ 16.79800034  16.19346237  17.41295624]
# Found 827454 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 77
# fraction: 23876 46397 0.515
#
# Snapshot number: 77
# fraction: 9620 12381 0.777
#
# Snapshot number: 77
# fraction: 529 2096 0.252
#
# [ 17.20534706  16.5902729   17.85304451]
# Found 863745 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 78
# fraction: 26341 48450 0.544
#
# Snapshot number: 78
# fraction: 9186 11875 0.774
#
# Snapshot number: 78
# fraction: 534 1993 0.268
#
# [ 17.53638649  16.91461563  18.2147541 ]
# Found 881996 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 79
# fraction: 26217 47264 0.555
#
# Snapshot number: 79
# fraction: 8921 11857 0.752
#
# Snapshot number: 79
# fraction: 536 1917 0.28
#
# [ 17.78905106  17.16118431  18.49117279]
# Found 899956 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 80
# fraction: 27067 48888 0.554
#
# Snapshot number: 80
# fraction: 8971 11770 0.762
#
# Snapshot number: 80
# fraction: 542 2178 0.249
#
# [ 18.13132668  17.49447441  18.86812019]
# Found 925630 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 81
# fraction: 27768 51392 0.54
#
# Snapshot number: 81
# fraction: 545 1940 0.281
#
# Snapshot number: 81
# fraction: 8722 11577 0.753
#
# [ 18.48038101  17.83345413  19.25479507]
# Found 968627 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 82
# fraction: 29297 53279 0.55
#
# Snapshot number: 82
# fraction: 558 2191 0.255
#
# Snapshot number: 82
# fraction: 0 635 0.0
#
# [ 18.83633041  18.17889214  19.65101624]
# Found 1008197 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 83
# fraction: 30156 54296 0.555
#
# Snapshot number: 83
# fraction: 566 1894 0.299
#
# Snapshot number: 83
# fraction: 0 655 0.0
#
# [ 19.10744095  18.44243622  19.95356178]
# Found 1021584 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 84
# fraction: 30981 57387 0.54
#
# Snapshot number: 84
# fraction: 562 2121 0.265
#
# Snapshot number: 84
# fraction: 0 726 0.0
#
# [ 19.47507477  18.79951668  20.36402512]
# Found 1059935 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 85
# fraction: 31574 57716 0.547
#
# Snapshot number: 85
# fraction: 580 2007 0.289
#
# Snapshot number: 85
# fraction: 0 668 0.0
#
# [ 19.75509262  19.0717144   20.67724609]
# Found 1081667 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 86
# fraction: 32230 59198 0.544
#
# Snapshot number: 86
# fraction: 585 2176 0.269
#
# Snapshot number: 86
# fraction: 0 647 0.0
#
# [ 20.13412285  19.44070625  21.10229874]
# Found 1120839 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 87
# fraction: 32937 60704 0.543
#
# Snapshot number: 87
# fraction: 0 1773 0.0
#
# Snapshot number: 87
# fraction: 595 2300 0.259
#
# [ 20.42412758  19.72184372  21.42675972]
# Found 1154417 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 88
# fraction: 33570 63436 0.529
#
# Snapshot number: 88
# fraction: 0 1685 0.0
#
# Snapshot number: 88
# fraction: 600 2043 0.294
#
# [ 20.81840324  20.10211563  21.86827469]
# Found 1194051 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 89
# fraction: 34254 63328 0.541
#
# Snapshot number: 89
# fraction: 0 1681 0.0
#
# Snapshot number: 89
# fraction: 607 2053 0.296
#
# [ 21.11937714  20.39230919  22.20462799]
# Found 1227647 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 90
# fraction: 35126 65964 0.533
#
# Snapshot number: 90
# fraction: 0 1485 0.0
#
# Snapshot number: 90
# fraction: 584 1797 0.325
#
# [ 21.42389488  20.68611908  22.54693604]
# Found 1255435 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 91
# fraction: 9 37615 0.0
#
# Snapshot number: 91
# fraction: 36032 67844 0.531
#
# Snapshot number: 91
# fraction: 3 6983 0.0
#
# [ 21.73373222  20.98360252  22.89403915]
# Found 1283929 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 92
# fraction: 8 39967 0.0
#
# Snapshot number: 92
# fraction: 37086 73689 0.503
# Snapshot number: 92
# fraction: 3 5621 0.001
#
# [ 22.153759    21.38641167  23.364851  ]
# Found 1315974 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 93
# fraction: 9 41159 0.0
#
# Snapshot number: 93
# fraction: 38292 72060 0.531
#
# Snapshot number: 93
# fraction: 2 8454 0.0
#
# [ 22.47373009  21.69274902  23.72468185]
# Found 1349298 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 94
# fraction: 11 43920 0.0
#
# Snapshot number: 94
# fraction: 38140 71232 0.535
#
# Snapshot number: 94
# fraction: 0 2072 0.0
#
# [ 22.7996521   22.0025444   24.08984756]
# Found 1373081 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 95
# fraction: 14 44374 0.0
#
# Snapshot number: 95
# fraction: 33803 63373 0.533
#
# Snapshot number: 95
# fraction: 0 2073 0.0
#
# [ 23.13161278  22.31706619  24.45867538]
# Found 1400280 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 96
# fraction: 10 44143 0.0
#
# Snapshot number: 96
# fraction: 37502 66847 0.561
#
# Snapshot number: 96
# fraction: 0 1584 0.0
#
# [ 23.46821594  22.63773918  24.8325634 ]
# Found 1416479 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 97
# fraction: 7 43654 0.0
#
# Snapshot number: 97
# fraction: 35373 64679 0.547
#
# Snapshot number: 97
# fraction: 0 7394 0.0
#
# [ 23.80860329  22.96368408  25.21352386]
# Found 1428816 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 98
# fraction: 5 43341 0.0
#
# Snapshot number: 98
# fraction: 38190 67721 0.564
#
# Snapshot number: 98
# fraction: 0 2044 0.0
#
# [ 24.15342522  23.29395103  25.60112953]
# Found 1445387 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 99
# fraction: 3 46607 0.0
#
# Snapshot number: 99
# fraction: 37606 67989 0.553
#
# Snapshot number: 99
# fraction: 0 1469 0.0
#
# [ 24.50271797  23.62892342  25.99520683]
# Found 1470007 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 100
# fraction: 8 51796 0.0
#
# Snapshot number: 100
# fraction: 38956 70708 0.551
#
# Snapshot number: 100
# fraction: 0 7449 0.0
#
# [ 24.85713387  23.96839905  26.39595032]
# Found 1484340 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 101
# fraction: 10 58417 0.0
#
# Snapshot number: 101
# fraction: 0 20845 0.0
#
# Snapshot number: 101
# fraction: 38952 72676 0.536
#
# [ 25.21674347  24.31293106  26.80324364]
# Found 1494084 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 102
# fraction: 11 59882 0.0
#
# Snapshot number: 102
# fraction: 0 19825 0.0
#
# Snapshot number: 102
# fraction: 38231 71455 0.535
#
# [ 25.45941925  24.54529381  27.07883453]
# Found 1509390 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 103
# fraction: 10 60483 0.0
#
# Snapshot number: 103
# fraction: 0 22283 0.0
#
# Snapshot number: 103
# fraction: 30594 60784 0.503
#
# [ 25.82858849  24.89687347  27.49774933]
# Found 1532350 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 104
# fraction: 8 60317 0.0
#
# Snapshot number: 104
# fraction: 2 37094 0.0
#
# Snapshot number: 104
# fraction: 0 24742 0.0
#
# [ 26.2042942   25.2542057   27.92131042]
# Found 1524327 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 105
# fraction: 5 63034 0.0
#
# Snapshot number: 105
# fraction: 2 36868 0.0
#
# Snapshot number: 105
# fraction: 0 26821 0.0
#
# [ 26.58517647  25.61821175  28.35095024]
# Found 1553881 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 106
# fraction: 6 64280 0.0
#
# Snapshot number: 106
# fraction: 2 42012 0.0
#
# Snapshot number: 106
# fraction: 0 22910 0.0
#
# [ 26.97145081  25.98770905  28.78736305]
# Found 1562371 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 107
# fraction: 2 68244 0.0
#
# Snapshot number: 107
# fraction: 2 49946 0.0
#
# Snapshot number: 107
# fraction: 0 22454 0.0
#
# [ 27.23214722  26.23708725  29.08192825]
# Found 1625123 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 108
# fraction: 5 70532 0.0
#
# Snapshot number: 108
# fraction: 0 42543 0.0
#
# Snapshot number: 108
# fraction: 0 25191 0.0
#
# [ 27.62681198  26.61546135  29.52968025]
# Found 1597012 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 109
# fraction: 1 72795 0.0
#
# Snapshot number: 109
# fraction: 0 42797 0.0
#
# Snapshot number: 109
# fraction: 0 27531 0.0
#
# [ 28.02821541  26.99830246  29.98339081]
# Found 1596516 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 110
# fraction: 5 71813 0.0
#
# Snapshot number: 110
# fraction: 0 43814 0.0
#
# Snapshot number: 110
# fraction: 0 23255 0.0
#
# [ 28.29884148  27.25717163  30.28975487]
# Found 1611388 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 111
# fraction: 6 76943 0.0
#
# Snapshot number: 111
# fraction: 0 41807 0.0
#
# Snapshot number: 111
# fraction: 0 23632 0.0
#
# [ 28.71037102  27.65019417  30.75450516]
# Found 1681756 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 112
# fraction: 6 78704 0.0
#
# Snapshot number: 112
# fraction: 0 42901 0.0
#
# Snapshot number: 112
# fraction: 0 31345 0.0
#
# [ 29.12677383  28.04948807  31.22624779]
# Found 1636296 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 113
# fraction: 6 80659 0.0
#
# Snapshot number: 113
# fraction: 0 42001 0.0
#
# Snapshot number: 113
# fraction: 0 23996 0.0
#
# [ 29.40730476  28.31895065  31.54471207]
# Found 1680675 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 114
# fraction: 6 88920 0.0
#
# Snapshot number: 114
# fraction: 0 42484 0.0
#
# Snapshot number: 114
# fraction: 0 22712 0.0
#
# [ 29.83269691  28.72842789  32.02832794]
# Found 1689680 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 115
# fraction: 5 88563 0.0
#
# Snapshot number: 115
# fraction: 0 43878 0.0
#
# Snapshot number: 115
# fraction: 0 26278 0.0
#
# [ 30.11922264  29.0051918   32.35468674]
# Found 1690508 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 116
# fraction: 4 90706 0.0
#
# Snapshot number: 116
# fraction: 0 43505 0.0
#
# Snapshot number: 116
# fraction: 0 33482 0.0
#
# [ 30.55345726  29.42549706  32.85093689]
# Found 1709507 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 117
# fraction: 4 92851 0.0
#
# Snapshot number: 117
# fraction: 0 44709 0.0
#
# Snapshot number: 117
# fraction: 0 28430 0.0
#
# [ 30.99422073  29.85132217  33.35467911]
# Found 1704816 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 118
# fraction: 4 93346 0.0
#
# Snapshot number: 118
# fraction: 0 46445 0.0
#
# Snapshot number: 118
# fraction: 0 25707 0.0
#
# [ 31.29102707  30.13891983  33.69516754]
# Found 1717424 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 119
# fraction: 4 95646 0.0
#
# Snapshot number: 119
# fraction: 0 48701 0.0
#
# Snapshot number: 119
# fraction: 0 27005 0.0
#
# [ 31.74212646  30.57429314  34.21273041]
# Found 1726323 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 120
# fraction: 4 95829 0.0
#
# Snapshot number: 120
# fraction: 0 47252 0.0
#
# Snapshot number: 120
# fraction: 0 27579 0.0
#
# [ 32.04627228  30.8679924   34.56239319]
# Found 1736454 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 121
# fraction: 3 100093 0.0
#
# Snapshot number: 121
# fraction: 0 46360 0.0
#
# Snapshot number: 121
# fraction: 0 29635 0.0
#
# [ 32.50867844  31.31370544  35.09283066]
# Found 1755643 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 122
# fraction: 2 102893 0.0
#
# Snapshot number: 122
# fraction: 0 47052 0.0
#
# Snapshot number: 122
# fraction: 0 31444 0.0
#
# [ 32.82047653  31.61475182  35.45058823]
# Found 1755878 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 123
# fraction: 1 105278 0.0
#
# Snapshot number: 123
# fraction: 0 47015 0.0
#
# Snapshot number: 123
# fraction: 0 28973 0.0
#
# [ 33.29346848  32.07149124  35.99433899]
# Found 1758643 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 124
# fraction: 0 113792 0.0
#
# Snapshot number: 124
# fraction: 0 49310 0.0
#
# Snapshot number: 124
# fraction: 0 29518 0.0
#
# [ 33.61259842  32.37949753  36.36141205]
# Found 1769475 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 125
# fraction: 0 362345 0.0
#
# Snapshot number: 125
# fraction: 0 107545 0.0
#
# Snapshot number: 125
# fraction: 0 48520 0.0
#
# [ 34.09642792  32.84707642  36.91917419]
# Found 1774142 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 126
# fraction: 0 368105 0.0
#
# Snapshot number: 126
# fraction: 0 109887 0.0
#
# Snapshot number: 126
# fraction: 0 50501 0.0
#
# [ 34.42281723  33.16259384  37.29567337]
# Found 1783163 stars.
# Rotated pos.
# Rotated vel.
# check works
# Snapshot number: 127
# fraction: 0 372995 0.0
#
# Snapshot number: 127
# fraction: 0 110611 0.0
#
# Snapshot number: 127
# fraction: 0 50861 0.0
