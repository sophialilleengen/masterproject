# %%
machine = 'mac'
machine = 'magny'

# %%
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
from mpl_toolkits.mplot3d import Axes3D
import copy

from areposnap.gadget import gadget_readsnap
from areposnap.gadget_subfind import load_subfind

from auriga_basics import *
from auriga_functions import *
# %matplotlib inline

# %%
#### path = /hits/universe/GigaGalaxy/level4_MHD/halo_24/output/*
level = 4
if machine == 'magny':
    basedir = "/hits/universe/GigaGalaxy/level4_MHD/"
elif machine == 'mac': 
    basedir = "/Users/smilanov/Desktop/Auriga/level4/"
j = 0
for halo_number in [24]:  # range(1, 31):
    halodir = basedir+"halo_{0}/".format(halo_number)
    snappath = halodir+"output/"
    '''
    s_main, sf_main =  eat_snap_and_fof(level, halo_number, 127, snappath, loadonlytype=[4], 
            haloid=0, galradfac=0.1, verbose=True) 
    s_main.data['gmet'] = np.maximum( s_main.data['gmet'], 1e-40 )
    istars, = np.where( (s.type == 4) & (s.halo == 0) )
    (x_main_Mpc, y_main_Mpc, z_main_Mpc), (vx_main_Mpc, vy_main_Mpc, vz_main_Mpc), rxyz_main_Mpc, rxy_main_Mpc = get_cartesian_vectors(s, sf, istars)
    '''
    for snapnr in [127]:
        print("level   : {0}".format(level))
        print("halo    : {0}".format(halo_number))
        print("snapnr  : {0}".format(snapnr))
        print("basedir : {0}".format(basedir))
        print("halodir : {0}".format(halodir))
        print("snappath: {0}\n".format(snappath))
        s, sf = eat_snap_and_fof(level, halo_number, snapnr, snappath, loadonlytype=[4], 
            haloid=0, galradfac=0.1, verbose=True) 

        # Clean negative and zero values of gmet to avoid RuntimeErrors
        # later on (e.g. dividing by zero)
        s.data['gmet'] = np.maximum( s.data['gmet'], 1e-40 )
# Out:
# level   : 4
# halo    : 24
# snapnr  : 127
# basedir : /hits/universe/GigaGalaxy/level4_MHD/
# halodir : /hits/universe/GigaGalaxy/level4_MHD/halo_24/
# snappath: /hits/universe/GigaGalaxy/level4_MHD/halo_24/output/
#
# [ 34.42281723  33.16259384  37.29567337]
# Found 1783163 stars.
# Rotated pos.
# Rotated vel.
#
# galrad  : 0.02408556640148163
# redshift: 2.220446049250313e-16
# time    : 0.9999999999999998
# center  : [ 0.  0.  0.]

# %%
def dwarf_selection(s, sf, z_kpc_val, level, halo_number, snapnr, snappath, subhalonr, partnr, verbose = True, outplot = True, outfile = False, saveplot = False):
    '''
    NAME: 
        dwarf_selection
    INPUT:
        s, sf: z=0 snapshot
        z_kpc: absolute disk height in kpc
        level, halo_number, snapnr, snappath: snapshot in which dwarf is selected (INT; 0 < snapnr < 127)
        subhalonr: which subhalo should be selected (INT; 0 < subhalonr)
        partnr: number of random selected dwarf particles (INT)
        outplot: if True, plots marked dwarf in early and z=0 snapshot; default = True
        outfile: if True, saves information on dwarfs in file; default = False
    HISTORY:
        02-02-2018: written (Milanov, ESO)
    '''
    # read in early snapshot
    try:
        es, esf = eat_snap_and_fof(level, halo_number, snapnr, snappath, loadonlytype=[4], 
                haloid=0, galradfac=0.1, verbose=False)   
    except KeyError:
        return
    except IndexError:
        return
    es.data['gmet'] = np.maximum( es.data['gmet'], 1e-40 )
    
    
    if isinstance(subhalonr, list):
        outstr = ''

        for item in subhalonr:
            istarssub, = np.where( (es.type == 4) & (es.halo == 0) & (es.subhalo == item) )
            try:
                istarssubsample = np.random.choice(istarssub, partnr)
            except ValueError:
                break
            #istarssubsample = np.where( (es.type == 4) & (es.halo == 0) & (es.subhalo == 1) & (1000. * np.abs(es.pos[::,0]) > z_kpc))
            ids_halo1 = es.id[istarssubsample]
            ids_halo1 = es.id[istarssub]



            istars, = np.where( (s.type == 4) & (s.halo == 0) )
            (x_kpc, y_kpc, z_kpc), (vx_kpc, vy_kpc, vz_kpc), rxyz_kpc, rxy_kpc = get_cartesian_vectors(s, sf, istars)
            istarse, = np.where( (es.type == 4) & (es.halo == 0) )
            (ex_kpc, ey_kpc, ez_kpc), (evx_kpc, evy_kpc, evz_kpc), erxyz_kpc, erxy_kpc = get_cartesian_vectors(es, esf, istarse)

            subhalomask = np.isin(s.id[istars], ids_halo1)
            esubhalomask = np.isin(es.id[istarse], ids_halo1)
            z_sample = np.where((np.abs(z_kpc) > z_kpc_val) & (rxyz_kpc < 5. * 1000. * s.galrad), True, False)


            survivors = np.sum(z_sample * subhalomask)
            starters = np.sum(esubhalomask)
            frac = round(survivors/starters, 3)
            outstr += '\tSH:' + str(item) + '\t' + str(frac) + '\t' + str(survivors) + '\t' + str(starters)

            if verbose == True:
                print('Snapshot number:', snapnr,'\nfraction:', survivors , starters, frac, '\n')
            if outplot == True:
                fig, axes = plt.subplots(2, 2, figsize=(12, 12))     
                axes[0, 0].set_title('Snapshot {:d}, Subhalo {:d}'.format(snapnr, item))
                axes[0, 0].hist2d(ex_kpc, ey_kpc, bins=401, norm=matplotlib.colors.LogNorm(), cmap = 'Greys')
                axes[0, 0].plot(ex_kpc[esubhalomask], ey_kpc[esubhalomask], '.', alpha = 0.2, color = 'xkcd:hot pink')
                axes[0, 0].set_xlabel("x")
                axes[0, 0].set_ylabel("y")
                axes[0, 0].set_aspect('equal')
                axes[0, 1].hist2d(erxy_kpc, ez_kpc, bins=401, norm=matplotlib.colors.LogNorm(), cmap = 'Greys')
                axes[0, 1].plot(erxy_kpc[esubhalomask], ez_kpc[esubhalomask], '.', alpha = 0.2, color = 'xkcd:hot pink')
                axes[0, 1].set_xlabel("R")
                axes[0, 1].set_ylabel("z")
                axes[0, 1].set_aspect('equal')

                axes[1, 0].hist2d(x_kpc, y_kpc, bins=401, norm=matplotlib.colors.LogNorm(), cmap = 'Greys')
                axes[1, 0].plot(x_kpc[z_sample * subhalomask], y_kpc[z_sample * subhalomask], '.', alpha = 0.2, color = 'xkcd:hot pink')
                axes[1, 0].set_xlabel("x")
                axes[1, 0].set_ylabel("y")
                axes[1, 0].set_aspect('equal')
                axes[1, 1].set_title('Disk height = {:.1f} kpc'.format(2.*z_disk_kpc))
                axes[1, 1].hist2d(rxy_kpc, z_kpc, bins=401, norm=matplotlib.colors.LogNorm(), cmap = 'Greys')
                axes[1, 1].plot(rxy_kpc[z_sample * subhalomask], z_kpc[z_sample * subhalomask], '.', alpha = 0.2, color = 'xkcd:hot pink')
                axes[1, 1].set_xlabel("R")
                axes[1, 1].set_ylabel("z")
                axes[1, 1].set_aspect('equal')
                #fig.show()
            if saveplot == True:
                fig.savefig('/home/extmilan/masterthesis/plots/dwarf_selection_snap_{:d}_SH_{:d}.png'.format(snapnr, item), dpi=300, facecolor='w', edgecolor='w',format='png')
            
        snap_time = s.cosmology_get_lookback_time_from_a( es.time, is_flat=True )
        snap_redshift = es.redshift
        #survivor_age = star_age[z_sample * subhalomask]
        if outfile == True:
            with open('/home/extmilan/masterthesis/files/test2.txt','a') as f:
                f.write(str(snapnr) + '\t' + str(snap_time) + '\t' + str(snap_redshift) + outstr + '\n')
   

    else:
        istarssub, = np.where( (es.type == 4) & (es.halo == 0) & (es.subhalo == subhalonr) )
        istarssubsample = np.random.choice(istarssub, partnr)
        #istarssubsample = np.where( (es.type == 4) & (es.halo == 0) & (es.subhalo == 1) & (1000. * np.abs(es.pos[::,0]) > z_kpc))
        ids_halo1 = es.id[istarssubsample]
        ids_halo1 = es.id[istarssub]

        istarsmain, = np.where( (s.type == 4) & (s.halo == 0) & (s.subhalo ==0))
        (x_kpc_m, y_kpc_m, z_kpc_m), (vx_kpc_m, vy_kpc_m, vz_kpc_m), rxyz_kpc_m, rxy_kpc_m = get_cartesian_vectors(s, sf, istarsmain)


        istars, = np.where( (s.type == 4) & (s.halo == 0) )
        (x_kpc, y_kpc, z_kpc), (vx_kpc, vy_kpc, vz_kpc), rxyz_kpc, rxy_kpc = get_cartesian_vectors(s, sf, istars)
        istarse, = np.where( (es.type == 4) & (es.halo == 0) )
        (ex_kpc, ey_kpc, ez_kpc), (evx_kpc, evy_kpc, evz_kpc), erxyz_kpc, erxy_kpc = get_cartesian_vectors(es, esf, istarse)

        subhalomask = np.isin(s.id[istarsmain], ids_halo1)
        esubhalomask = np.isin(es.id[istarse], ids_halo1)
        z_sample = np.logical_not((np.abs(z_kpc_m) < z_kpc_val) & (rxy_kpc_m < 1000. * s.galrad))
        Galrad = 1000.*s.galrad

        
        
        survivors = np.sum(z_sample * subhalomask)
        starters = np.sum(esubhalomask)
        main_gal = np.sum( (es.type == 4) & (es.halo == 0) & (es.subhalo == 0))
        frac = round(survivors/starters, 3)

        snap_time = s.cosmology_get_lookback_time_from_a( es.time, is_flat=True )
        snap_redshift = es.redshift
        #survivor_age = star_age[z_sample * subhalomask]


        if verbose == True:
            print('Snapshot number:', snapnr,'\nfraction:', survivors , starters, frac, '\nstars in main galaxy: {:d}\n'.format(main_gal))
        if outplot == True:
            fig, axes = plt.subplots(2, 2, figsize=(12, 12))     
            axes[0, 0].set_title('Snapshot {:d}, Subhalo {:d}'.format(snapnr, subhalonr))
            axes[0, 0].hist2d(ex_kpc, ey_kpc, bins=401, norm=matplotlib.colors.LogNorm(), cmap = 'Greys')
            axes[0, 0].plot(ex_kpc[esubhalomask], ey_kpc[esubhalomask], '.', alpha = 0.3, color = 'xkcd:hot pink')
            axes[0, 0].set_xlabel("x [kpc]")
            axes[0, 0].set_ylabel("y [kpc]")
            axes[0, 0].set_aspect('equal')
            axes[0, 1].hist2d(erxy_kpc, ez_kpc, bins=401, norm=matplotlib.colors.LogNorm(), cmap = 'Greys')
            axes[0, 1].plot(erxy_kpc[esubhalomask], ez_kpc[esubhalomask], '.', alpha = 0.3, color = 'xkcd:hot pink')
            axes[0, 1].set_xlabel("R [kpc]")
            axes[0, 1].set_ylabel("z [kpc]")
            axes[0, 1].set_aspect('equal')
            
            axes[1, 0].set_title('Snapshot {:d}'.format(127))
            axes[1, 0].set_title('Snapshot {:d}, Subhalo {:d} from snapshot {:d}'.format(127, subhalonr, 67))
            axes[1, 0].hist2d(x_kpc, y_kpc, bins=401, norm=matplotlib.colors.LogNorm(), cmap = 'Greys')
            axes[1, 0].plot(x_kpc_m[z_sample * subhalomask], y_kpc_m[z_sample * subhalomask], '.', alpha = 0.3, color = 'xkcd:hot pink')
            axes[1, 0].set_xlabel("x [kpc]")
            axes[1, 0].set_ylabel("y [kpc]")
            axes[1, 0].set_aspect('equal')
            axes[1, 0].annotate('nr survivors: {:d}\nfraction: {:.3f}'.format(survivors, frac), 
                            xy=(1, 0), xycoords='axes fraction', fontsize=12,
                horizontalalignment='right', verticalalignment='bottom')
            axes[1, 1].set_title('Disk height = {:.1f} kpc, Disk radius = {:.1f}'.format(2.*z_disk_kpc, Galrad))        
            axes[1, 1].hist2d(rxy_kpc, z_kpc, bins=401, norm=matplotlib.colors.LogNorm(), cmap = 'Greys')
            axes[1, 1].plot(rxy_kpc_m[z_sample * subhalomask], z_kpc_m[z_sample * subhalomask], '.', alpha = 0.3, color = 'xkcd:hot pink')
            axes[1, 1].set_xlabel("R [kpc]")
            axes[1, 1].set_ylabel("z [kpc]")
            axes[1, 1].set_aspect('equal')
            #fig.show()
        if saveplot == True:
            fig.savefig('/home/extmilan/masterthesis/plots/dwarf_selection_snap_{:d}_SH_{:d}.png'.format(snapnr, subhalonr), dpi=100, facecolor='w', edgecolor='w',format='png')


        if outfile == True:
            with open('/home/extmilan/masterthesis/files/dwarf_evolution_all_snapshots_1st_SH.txt','a') as f:
                f.write('{:d}\t\t{:.3f}\t{:.3f}\t\t{:.3f}\t{:d}\t{:d}\t\t{:d}\n'.format(snapnr, snap_time, snap_redshift, frac, survivors, starters, main_gal))

# %%
halo_number = 24
halodir = basedir+"halo_{0}/".format(halo_number)
snappath = halodir+"output/"
z_disk_kpc = 1.
Galrad = 1000*s.galrad
first_comm = 'Halo {:d}; disk_height: {:.1f} kpc; diskwidth: {:.2f} kpc\nSnapnr; Age; Redshift; surviving fraction; nr of survivors; nr of dwarf stars; nr of main gal stars\n'.format(halo_number, 2*z_disk_kpc, Galrad)

with open('/home/extmilan/masterthesis/files/dwarf_evolution_all_snapshots_1st_SH.txt','a') as f:
    f.write(first_comm)

for i in range(0,128,1):
    dwarf_selection(s, sf, z_disk_kpc, level, halo_number, i, snappath, 1, 50, outfile = True, outplot= False, saveplot = False)
# Out:
# [ 0.68997848  0.73377794  0.72552913]
# ../../anaconda3/lib/python3.6/site-packages/areposnap/gadget_snap.py:1515: RuntimeWarning: invalid value encountered in true_divide
#   vel = (self.vel[iall,:] * mass[iall][:,None]).sum(axis=0) / mass[iall].sum()
# [ 0.7234897   0.76935881  0.76080716]
# [ 0.768911    0.81777596  0.78662628]
# [ 0.80237359  0.85338241  0.82094795]
# Found 0 stars.
# ../../anaconda3/lib/python3.6/site-packages/areposnap/gadget_snap.py:1545: RuntimeWarning: invalid value encountered in true_divide
#   Ldir = Ltot / sqrt( (Ltot**2).sum() )
# [ 0.82093781  0.76843476  0.86288393]
# Found 0 stars.
# [ 0.86797398  0.79862845  0.87235445]
# Found 0 stars.
# [ 0.990309    0.81678659  0.9078902 ]
# Found 0 stars.
# [ 1.00251687  0.93924028  1.00887811]
# Found 0 stars.
# [ 1.05116498  0.98489976  1.05819023]
# Found 0 stars.
# [ 1.10215628  1.03271687  1.10996389]
# Found 0 stars.
# [ 1.155689    1.08288169  1.16423106]
# Found 0 stars.
# [ 1.21178746  1.13550091  1.22114444]
# Found 0 stars.
# [ 1.26454604  1.18501997  1.27483451]
# Found 0 stars.
# [ 1.32594752  1.24260163  1.33726978]
# Found 0 stars.
# [ 1.39032078  1.30296481  1.40279269]
# Found 0 stars.
# [ 1.45787263  1.36626518  1.47153223]
# Found 0 stars.
# [ 1.52146435  1.42590559  1.53629541]
# Found 0 stars.
# [ 1.56192708  1.51133966  1.48895395]
# Found 0 stars.
# [ 1.63803804  1.58520019  1.56137872]
# Found 0 stars.
# [ 1.71728933  1.66236067  1.63795924]
# Found 0 stars.
# [ 1.79199338  1.73505008  1.710145  ]
# Found 0 stars.
# [ 1.87885857  1.81956458  1.79405308]
# Found 0 stars.
# [ 1.96997511  1.90820003  1.88173497]
# Found 0 stars.
# [ 2.06547499  2.0011797   1.97422838]
# Found 1 stars.
# [ 2.15539694  2.08879709  2.06132317]
# Found 0 stars.
# [ 2.25987601  2.19063401  2.16238689]
# Found 0 stars.
# [ 2.3694756   2.29740047  2.2686007 ]
# Found 4 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 26
# fraction: 0 8 0.0
# stars in main galaxy: 89
#
# [ 2.48446131  2.40939927  2.38007212]
# Found 2 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 27
# fraction: 0 10 0.0
# stars in main galaxy: 117
#
# [ 2.60516763  2.52686286  2.49723887]
# Found 1 stars.
# [ 2.71875334  2.63748837  2.60741425]
# Found 6 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 29
# fraction: 3 17 0.176
# stars in main galaxy: 257
#
# [ 2.83273578  2.61936808  2.86838841]
# Found 3 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 30
# fraction: 0 26 0.0
# stars in main galaxy: 470
#
# [ 2.96990299  2.74538374  3.00988245]
# Found 3 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 31
# fraction: 0 114 0.0
# stars in main galaxy: 160
#
# [ 3.18649602  2.90000153  3.03076434]
# Found 41 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 32
# fraction: 1 15 0.067
# stars in main galaxy: 547
#
# [ 3.24688745  2.99542761  3.30316663]
# Found 9 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 33
# fraction: 0 187 0.0
# stars in main galaxy: 215
#
# [ 3.48630524  3.1776216   3.32057261]
# Found 66 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 34
# fraction: 0 6 0.0
# stars in main galaxy: 957
#
# [ 3.57852936  3.41344523  3.59672785]
# Found 77 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 35
# fraction: 14 87 0.161
# stars in main galaxy: 884
#
# [ 3.88295197  3.44158649  3.88973498]
# Found 100 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 36
# fraction: 0 48 0.0
# stars in main galaxy: 1648
#
# [ 3.94040155  3.67384386  3.99745083]
# Found 161 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 37
# fraction: 0 258 0.0
# stars in main galaxy: 1706
#
# [ 4.2451396   3.77268314  4.26102448]
# Found 290 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 38
# fraction: 0 13 0.0
# stars in main galaxy: 2592
#
# [ 4.26593399  4.15669727  4.23909092]
# Found 266 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 39
# fraction: 99 346 0.286
# stars in main galaxy: 1519
#
# [ 4.4739275   4.36128616  4.45105314]
# Found 420 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 40
# fraction: 92 200 0.46
# stars in main galaxy: 2906
#
# [ 4.76203728  4.62393808  4.62059116]
# Found 141 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 41
# fraction: 289 893 0.324
# stars in main galaxy: 1624
#
# [ 4.96745539  4.70612574  4.95621538]
# Found 305 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 42
# fraction: 150 815 0.184
# stars in main galaxy: 2280
#
# [ 5.20717669  4.93739939  5.20081854]
# Found 282 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 43
# fraction: 163 769 0.212
# stars in main galaxy: 3227
#
# [ 5.45930004  5.18125677  5.45793629]
# Found 565 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 44
# fraction: 62 361 0.172
# stars in main galaxy: 5732
#
# [ 5.73010778  5.57186985  5.58295202]
# Found 2910 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 45
# fraction: 590 2481 0.238
# stars in main galaxy: 9419
#
# [ 6.00896454  5.84421682  5.86421728]
# Found 2192 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 46
# fraction: 796 2077 0.383
# stars in main galaxy: 6942
#
# [ 6.27321196  6.0990777   6.13107109]
# Found 2811 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 47
# fraction: 747 1072 0.697
# stars in main galaxy: 8214
#
# [ 6.56175327  6.25628424  6.60190868]
# Found 4498 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 48
# fraction: 1417 5954 0.238
# stars in main galaxy: 10372
#
# [ 6.87784338  6.56649303  6.93449736]
# Found 4934 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 49
# fraction: 1780 4307 0.413
# stars in main galaxy: 12917
#
# [ 7.21020699  6.89154625  7.28530788]
# Found 6825 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 50
# fraction: 1951 4843 0.403
# stars in main galaxy: 18473
#
# [ 7.55916452  7.23123264  7.65299654]
# Found 9271 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 51
# fraction: 2268 5102 0.445
# stars in main galaxy: 19400
#
# [ 7.92679119  7.58518696  8.0392313 ]
# Found 11260 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 52
# fraction: 579 2922 0.198
# stars in main galaxy: 30301
#
# [ 8.3158474   7.95750761  8.43717575]
# Found 24087 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 53
# fraction: 645 1652 0.39
# stars in main galaxy: 44448
#
# [ 8.7214613   8.35234547  8.85930157]
# Found 33710 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 54
# fraction: 457 2121 0.215
# stars in main galaxy: 56368
#
# [ 9.10364056  8.72417164  9.26056767]
# Found 34349 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 55
# fraction: 567 1789 0.317
# stars in main galaxy: 59060
#
# [ 9.50209332  9.11564541  9.67981148]
# Found 41264 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 56
# fraction: 2696 7380 0.365
# stars in main galaxy: 69838
#
# [  9.87182808   9.4778223   10.06595612]
# Found 46848 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 57
# fraction: 20512 30114 0.681
# stars in main galaxy: 75443
#
# [ 10.25568104   9.85312176  10.46530151]
# Found 55529 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 58
# fraction: 22375 31518 0.71
# stars in main galaxy: 84084
#
# [ 10.60555553  10.19394493  10.82572174]
# Found 68232 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 59
# fraction: 24401 33300 0.733
# stars in main galaxy: 97007
#
# [ 10.96751499  10.54684067  11.19934082]
# Found 84249 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 60
# fraction: 26548 34851 0.762
# stars in main galaxy: 116877
#
# [ 11.33949471  10.91451645  11.58535576]
# Found 103761 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 61
# fraction: 6658 13174 0.505
# stars in main galaxy: 152461
#
# [ 11.72626972  11.2924757   11.99002552]
# Found 156728 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 62
# fraction: 7708 15475 0.498
# stars in main galaxy: 228809
#
# [ 12.06752777  11.62145424  12.35484123]
# Found 164288 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 63
# fraction: 8609 13542 0.636
# stars in main galaxy: 228319
#
# [ 12.42007446  11.95782089  12.73314667]
# Found 226624 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 64
# fraction: 9363 12133 0.772
# stars in main galaxy: 285158
#
# [ 12.78022385  12.30894375  13.11660862]
# Found 284600 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 65
# fraction: 6821 10640 0.641
# stars in main galaxy: 367856
#
# [ 13.08854771  12.60904121  13.44554806]
# Found 351151 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 66
# fraction: 7330 9773 0.75
# stars in main galaxy: 426271
#
# [ 13.4669323   12.98056126  13.84910297]
# Found 371337 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 67
# fraction: 40279 49161 0.819
# stars in main galaxy: 441791
#
# [ 13.78952217  13.29696274  14.19396877]
# Found 415479 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 68
# fraction: 41804 51605 0.81
# stars in main galaxy: 487711
#
# [ 14.12320042  13.61969185  14.55005264]
# Found 458329 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 69
# fraction: 43971 54375 0.809
# stars in main galaxy: 535920
#
# [ 14.46787739  13.95026779  14.91678429]
# Found 483558 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 70
# fraction: 47163 58782 0.802
# stars in main galaxy: 556699
#
# [ 14.82138062  14.29028893  15.29212379]
# Found 513965 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 71
# fraction: 51017 65869 0.775
# stars in main galaxy: 586932
#
# [ 15.1824646   14.63997269  15.67546272]
# Found 536367 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 72
# fraction: 54418 62557 0.87
# stars in main galaxy: 611646
#
# [ 15.47813797  14.92653275  15.98590374]
# Found 667800 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 73
# fraction: 22553 33901 0.665
# stars in main galaxy: 729398
#
# [ 15.85394859  15.28774834  16.39402962]
# Found 754347 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 74
# fraction: 26188 42841 0.611
# stars in main galaxy: 886060
#
# [ 16.16160011  15.58262157  16.72860718]
# Found 788548 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 75
# fraction: 29012 39831 0.728
# stars in main galaxy: 910940
#
# [ 16.47659492  15.88422775  17.06827354]
# Found 817842 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 76
# fraction: 29200 40289 0.725
# stars in main galaxy: 939261
#
# [ 16.79800034  16.19346237  17.41295624]
# Found 827454 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 77
# fraction: 30211 46397 0.651
# stars in main galaxy: 953919
#
# [ 17.20534706  16.5902729   17.85304451]
# Found 863745 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 78
# fraction: 33468 48450 0.691
# stars in main galaxy: 989134
#
# [ 17.53638649  16.91461563  18.2147541 ]
# Found 881996 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 79
# fraction: 33392 47264 0.706
# stars in main galaxy: 1004823
#
# [ 17.78905106  17.16118431  18.49117279]
# Found 899956 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 80
# fraction: 34492 48888 0.706
# stars in main galaxy: 1024733
#
# [ 18.13132668  17.49447441  18.86812019]
# Found 925630 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 81
# fraction: 35446 51392 0.69
# stars in main galaxy: 1049932
#
# [ 18.48038101  17.83345413  19.25479507]
# Found 968627 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 82
# fraction: 37385 53279 0.702
# stars in main galaxy: 1089865
#
# [ 18.83633041  18.17889214  19.65101624]
# Found 1008197 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 83
# fraction: 38474 54296 0.709
# stars in main galaxy: 1129269
#
# [ 19.10744095  18.44243622  19.95356178]
# Found 1021584 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 84
# fraction: 39538 57387 0.689
# stars in main galaxy: 1148479
#
# [ 19.47507477  18.79951668  20.36402512]
# Found 1059935 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 85
# fraction: 40293 57716 0.698
# stars in main galaxy: 1183301
#
# [ 19.75509262  19.0717144   20.67724609]
# Found 1081667 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 86
# fraction: 41099 59198 0.694
# stars in main galaxy: 1209731
#
# [ 20.13412285  19.44070625  21.10229874]
# Found 1120839 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 87
# fraction: 42029 60704 0.692
# stars in main galaxy: 1250040
#
# [ 20.42412758  19.72184372  21.42675972]
# Found 1154417 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 88
# fraction: 42884 63436 0.676
# stars in main galaxy: 1282707
#
# [ 20.81840324  20.10211563  21.86827469]
# Found 1194051 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 89
# fraction: 43751 63328 0.691
# stars in main galaxy: 1324392
#
# [ 21.11937714  20.39230919  22.20462799]
# Found 1227647 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 90
# fraction: 44823 65964 0.68
# stars in main galaxy: 1356992
#
# [ 21.42389488  20.68611908  22.54693604]
# Found 1255435 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 91
# fraction: 54 37615 0.001
# stars in main galaxy: 1388474
#
# [ 21.73373222  20.98360252  22.89403915]
# Found 1283929 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 92
# fraction: 58 39967 0.001
# stars in main galaxy: 1418635
#
# [ 22.153759    21.38641167  23.364851  ]
# Found 1315974 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 93
# fraction: 74 41159 0.002
# stars in main galaxy: 1453009
#
# [ 22.47373009  21.69274902  23.72468185]
# Found 1349298 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 94
# fraction: 291 43920 0.007
# stars in main galaxy: 1484055
#
# [ 22.7996521   22.0025444   24.08984756]
# Found 1373081 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 95
# fraction: 291 44374 0.007
# stars in main galaxy: 1518990
#
# [ 23.13161278  22.31706619  24.45867538]
# Found 1400280 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 96
# fraction: 317 44143 0.007
# stars in main galaxy: 1540917
#
# [ 23.46821594  22.63773918  24.8325634 ]
# Found 1416479 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 97
# fraction: 227 43654 0.005
# stars in main galaxy: 1565769
#
# [ 23.80860329  22.96368408  25.21352386]
# Found 1428816 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 98
# fraction: 197 43341 0.005
# stars in main galaxy: 1580323
#
# [ 24.15342522  23.29395103  25.60112953]
# Found 1445387 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 99
# fraction: 202 46607 0.004
# stars in main galaxy: 1602411
#
# [ 24.50271797  23.62892342  25.99520683]
# Found 1470007 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 100
# fraction: 345 51796 0.007
# stars in main galaxy: 1625213
#
# [ 24.85713387  23.96839905  26.39595032]
# Found 1484340 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 101
# fraction: 363 58417 0.006
# stars in main galaxy: 1649428
#
# [ 25.21674347  24.31293106  26.80324364]
# Found 1494084 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 102
# fraction: 391 59882 0.007
# stars in main galaxy: 1668850
#
# [ 25.45941925  24.54529381  27.07883453]
# Found 1509390 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 103
# fraction: 406 60483 0.007
# stars in main galaxy: 1691013
#
# [ 25.82858849  24.89687347  27.49774933]
# Found 1532350 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 104
# fraction: 380 60317 0.006
# stars in main galaxy: 1719180
#
# [ 26.2042942   25.2542057   27.92131042]
# Found 1524327 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 105
# fraction: 295 63034 0.005
# stars in main galaxy: 1731447
#
# [ 26.58517647  25.61821175  28.35095024]
# Found 1553881 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 106
# fraction: 301 64280 0.005
# stars in main galaxy: 1744666
#
# [ 26.97145081  25.98770905  28.78736305]
# Found 1562371 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 107
# fraction: 212 68244 0.003
# stars in main galaxy: 1765966
#
# [ 27.23214722  26.23708725  29.08192825]
# Found 1625123 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 108
# fraction: 222 70532 0.003
# stars in main galaxy: 1794412
#
# [ 27.62681198  26.61546135  29.52968025]
# Found 1597012 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 109
# fraction: 169 72795 0.002
# stars in main galaxy: 1815521
#
# [ 28.02821541  26.99830246  29.98339081]
# Found 1596516 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 110
# fraction: 242 71813 0.003
# stars in main galaxy: 1831299
#
# [ 28.29884148  27.25717163  30.28975487]
# Found 1611388 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 111
# fraction: 243 76943 0.003
# stars in main galaxy: 1841083
#
# [ 28.71037102  27.65019417  30.75450516]
# Found 1681756 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 112
# fraction: 285 78704 0.004
# stars in main galaxy: 1874577
#
# [ 29.12677383  28.04948807  31.22624779]
# Found 1636296 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 113
# fraction: 318 80659 0.004
# stars in main galaxy: 1885526
#
# [ 29.40730476  28.31895065  31.54471207]
# Found 1680675 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 114
# fraction: 318 88920 0.004
# stars in main galaxy: 1898179
#
# [ 29.83269691  28.72842789  32.02832794]
# Found 1689680 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 115
# fraction: 338 88563 0.004
# stars in main galaxy: 1912038
#
# [ 30.11922264  29.0051918   32.35468674]
# Found 1690508 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 116
# fraction: 319 90706 0.004
# stars in main galaxy: 1920791
#
# [ 30.55345726  29.42549706  32.85093689]
# Found 1709507 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 117
# fraction: 299 92851 0.003
# stars in main galaxy: 1935258
#
# [ 30.99422073  29.85132217  33.35467911]
# Found 1704816 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 118
# fraction: 318 93346 0.003
# stars in main galaxy: 1954420
#
# [ 31.29102707  30.13891983  33.69516754]
# Found 1717424 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 119
# fraction: 308 95646 0.003
# stars in main galaxy: 1968466
#
# [ 31.74212646  30.57429314  34.21273041]
# Found 1726323 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 120
# fraction: 296 95829 0.003
# stars in main galaxy: 1994481
#
# [ 32.04627228  30.8679924   34.56239319]
# Found 1736454 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 121
# fraction: 310 100093 0.003
# stars in main galaxy: 2014477
#
# [ 32.50867844  31.31370544  35.09283066]
# Found 1755643 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 122
# fraction: 245 102893 0.002
# stars in main galaxy: 2028740
#
# [ 32.82047653  31.61475182  35.45058823]
# Found 1755878 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 123
# fraction: 226 105278 0.002
# stars in main galaxy: 2038775
#
# [ 33.29346848  32.07149124  35.99433899]
# Found 1758643 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 124
# fraction: 137 113792 0.001
# stars in main galaxy: 2053345
#
# [ 33.61259842  32.37949753  36.36141205]
# Found 1769475 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 125
# fraction: 32 362345 0.0
# stars in main galaxy: 2060804
#
# [ 34.09642792  32.84707642  36.91917419]
# Found 1774142 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 126
# fraction: 18 368105 0.0
# stars in main galaxy: 2071683
#
# [ 34.42281723  33.16259384  37.29567337]
# Found 1783163 stars.
# Rotated pos.
# Rotated vel.
# Snapshot number: 127
# fraction: 0 372995 0.0
# stars in main galaxy: 2080318

# %%
def dwarf_following(Galrad, z_height_kpc, snappath, start_snap_nr, end_snap_nr = 127, subhalonr = 1, level = 4, halo_number = 24, outplot = True, outplotfirstlast = False, saveplotfirstlast = False, saveids = False):
    try:
        es, esf = eat_snap_and_fof(level, halo_number, start_snap_nr, snappath, loadonlytype=[4], 
                haloid=0, galradfac=0.1, verbose=False)   
    except KeyError:
        print('Start snapshot does not contain stars.')
        return
    except IndexError:
        print('Start snapshot does not contain stars.')
        return
    istarssub, = np.where( (es.type == 4) & (es.halo == 0) & (es.subhalo == subhalonr) )
    #istarssubsample = np.random.choice(istarssub, partnr)
    #ids_halo1 = es.id[istarssubsample]
    ids_halo1 = es.id[istarssub]
    nr_start_parts = len(ids_halo1)


    if outplotfirstlast == True:
        fig, axes = plt.subplots(2, 2, figsize=(12, 12))             
        istarse, = np.where( (es.type == 4) & (es.halo == 0) )
        (ex_kpc, ey_kpc, ez_kpc), (evx_kpc, evy_kpc, evz_kpc), erxyz_kpc, erxy_kpc = get_cartesian_vectors(es, esf, istarse)
        diskmask = np.logical_not((erxy_kpc < Galrad) & (np.abs(ez_kpc) < z_height_kpc))
        
        esubhalomask = np.isin(es.id[istarse*diskmask], ids_halo1)

        #fig, axes = plt.subplots(1, 2, figsize=(12, 12))     
        axes[0, 0].set_title('Snapshot {:d}, Subhalo {:d}'.format(start_snap_nr, subhalonr))
        axes[0, 0].hist2d(ex_kpc, ey_kpc, bins=401, norm=matplotlib.colors.LogNorm(), cmap = 'Greys')
        axes[0, 0].plot(ex_kpc[esubhalomask], ey_kpc[esubhalomask], '.', alpha = 0.3, color = 'xkcd:hot pink')
        axes[0, 0].set_xlabel("x [kpc]")
        axes[0, 0].set_ylabel("y [kpc]")
        axes[0, 0].set_aspect('equal')
        axes[0, 1].hist2d(erxy_kpc, ez_kpc, bins=401, norm=matplotlib.colors.LogNorm(), cmap = 'Greys')
        axes[0, 1].plot(erxy_kpc[esubhalomask], ez_kpc[esubhalomask], '.', alpha = 0.3, color = 'xkcd:hot pink')
        axes[0, 1].set_xlabel("R [kpc]")
        axes[0, 1].set_ylabel("z [kpc]")
        axes[0, 1].set_aspect('equal')
        
    for i in range(start_snap_nr, end_snap_nr + 1, 1):
        fs, fsf = eat_snap_and_fof(level, halo_number, i, snappath, loadonlytype=[4], 
                haloid=0, galradfac=0.1, verbose=False)   
        
        '''
        istars, = np.where( (s.type == 4) & (s.halo == 0) )
        (x_kpc, y_kpc, z_kpc), (vx_kpc, vy_kpc, vz_kpc), rxyz_kpc, rxy_kpc = get_cartesian_vectors(s, sf, istars)
        '''
        istarsf, = np.where( (fs.type == 4) & (fs.halo == 0) )
        (fx_kpc, fy_kpc, fz_kpc), (fvx_kpc, fvy_kpc, fvz_kpc), frxyz_kpc, frxy_kpc = get_cartesian_vectors(fs, fsf, istarsf)


        # disselect all particles which pass the disk (e.g. R < 1000*s.galrad, z < 1/1.5/2 kpc)
        diskmask = np.logical_not((frxy_kpc < Galrad) & (np.abs(fz_kpc) < z_height_kpc))
        
        fsubhalomask = np.isin(fs.id[istarsf*diskmask], ids_halo1)
        ids_halo1 = fs.id[istarsf*diskmask][fsubhalomask]
  
        if outplot == True:
            fig, axes = plt.subplots(1, 2, figsize=(12, 12))     
            axes[0].set_title('Snapshot {:d}, Subhalo {:d}'.format(i, subhalonr))
            axes[0].hist2d(fx_kpc, fy_kpc, bins=401, norm=matplotlib.colors.LogNorm(), cmap = 'Greys')
            axes[0].plot(fx_kpc[fsubhalomask], fy_kpc[fsubhalomask], '.', alpha = 0.3, color = 'xkcd:hot pink')
            axes[0].set_xlabel("x [kpc]")
            axes[0].set_ylabel("y [kpc]")
            axes[0].set_aspect('equal')
            axes[1].hist2d(frxy_kpc, fz_kpc, bins=401, norm=matplotlib.colors.LogNorm(), cmap = 'Greys')
            axes[1].plot(frxy_kpc[fsubhalomask], fz_kpc[fsubhalomask], '.', alpha = 0.3, color = 'xkcd:hot pink')
            axes[1].set_xlabel("R [kpc]")
            axes[1].set_ylabel("z [kpc]")
            axes[1].set_aspect('equal')

    nr_end_parts = len(ids_halo1)
    surv_frac = nr_end_parts/nr_start_parts

    if outplotfirstlast == True:
        #fig, axes = plt.subplots(1, 2, figsize=(12, 12))     
        axes[1, 0].set_title('Snapshot {:d}, Subhalo {:d} from snapshot {:d}'.format(end_snap_nr, subhalonr, start_snap_nr))
        axes[1, 0].hist2d(fx_kpc, fy_kpc, bins=401, norm=matplotlib.colors.LogNorm(), cmap = 'Greys')
        axes[1, 0].plot(fx_kpc[fsubhalomask], fy_kpc[fsubhalomask], '.', alpha = 0.3, color = 'xkcd:hot pink')
        axes[1, 0].set_xlabel("x [kpc]")
        axes[1, 0].set_ylabel("y [kpc]")
        axes[1, 0].set_aspect('equal')
        axes[1, 0].annotate('nr survivors: {:d}\nfraction: {:.3f}'.format(nr_end_parts, surv_frac), 
                            xy=(1, 0), xycoords='axes fraction', fontsize=12,
                horizontalalignment='right', verticalalignment='bottom')
        axes[1, 1].set_title('Disk height = {:.1f} kpc, Disk radius = {:.1f}'.format(2.*z_height_kpc, Galrad))        
        axes[1, 1].hist2d(frxy_kpc, fz_kpc, bins=401, norm=matplotlib.colors.LogNorm(), cmap = 'Greys')
        axes[1, 1].plot(frxy_kpc[fsubhalomask], fz_kpc[fsubhalomask], '.', alpha = 0.3, color = 'xkcd:hot pink')
        axes[1, 1].set_xlabel("R [kpc]")
        axes[1, 1].set_ylabel("z [kpc]")
        axes[1, 1].set_aspect('equal')
        if saveplotfirstlast == True:
            fig.savefig('/home/extmilan/masterthesis/plots/dwarf_selection_wodisk_snap_{:d}_SH_{:d}.png'.format(start_snap_nr, subhalonr), dpi=100, facecolor='w', edgecolor='w',format='png')
   
    print(surv_frac, nr_end_parts, nr_start_parts)
    if saveids == True:
        np.savetxt('/home/extmilan/masterthesis/files/surviving_ids_snapshot_{:d}_sh_1.txt'.format(start_snap_nr), ids_halo1, fmt = '%d')

# %%
Galrad = 1000.*s.galrad
dwarf_following(Galrad, 1., snappath, 67, 127, outplot = False, outplotfirstlast=True, saveplotfirstlast=False, saveids=True)
# Out:
# [ 13.4669323   12.98056126  13.84910297]
# Found 371337 stars.
# Rotated pos.
# Rotated vel.
# [ 13.4669323   12.98056126  13.84910297]
# Found 371337 stars.
# Rotated pos.
# Rotated vel.
# [ 13.78952217  13.29696274  14.19396877]
# Found 415479 stars.
# Rotated pos.
# Rotated vel.
# [ 14.12320042  13.61969185  14.55005264]
# Found 458329 stars.
# Rotated pos.
# Rotated vel.
# [ 14.46787739  13.95026779  14.91678429]
# Found 483558 stars.
# Rotated pos.
# Rotated vel.
# [ 14.82138062  14.29028893  15.29212379]
# Found 513965 stars.
# Rotated pos.
# Rotated vel.
# [ 15.1824646   14.63997269  15.67546272]
# Found 536367 stars.
# Rotated pos.
# Rotated vel.
# [ 15.47813797  14.92653275  15.98590374]
# Found 667800 stars.
# Rotated pos.
# Rotated vel.
# [ 15.85394859  15.28774834  16.39402962]
# Found 754347 stars.
# Rotated pos.
# Rotated vel.
# [ 16.16160011  15.58262157  16.72860718]
# Found 788548 stars.
# Rotated pos.
# Rotated vel.
# [ 16.47659492  15.88422775  17.06827354]
# Found 817842 stars.
# Rotated pos.
# Rotated vel.
# [ 16.79800034  16.19346237  17.41295624]
# Found 827454 stars.
# Rotated pos.
# Rotated vel.
# [ 17.20534706  16.5902729   17.85304451]
# Found 863745 stars.
# Rotated pos.
# Rotated vel.
# [ 17.53638649  16.91461563  18.2147541 ]
# Found 881996 stars.
# Rotated pos.
# Rotated vel.
# [ 17.78905106  17.16118431  18.49117279]
# Found 899956 stars.
# Rotated pos.
# Rotated vel.
# [ 18.13132668  17.49447441  18.86812019]
# Found 925630 stars.
# Rotated pos.
# Rotated vel.
# [ 18.48038101  17.83345413  19.25479507]
# Found 968627 stars.
# Rotated pos.
# Rotated vel.
# [ 18.83633041  18.17889214  19.65101624]
# Found 1008197 stars.
# Rotated pos.
# Rotated vel.
# [ 19.10744095  18.44243622  19.95356178]
# Found 1021584 stars.
# Rotated pos.
# Rotated vel.
# [ 19.47507477  18.79951668  20.36402512]
# Found 1059935 stars.
# Rotated pos.
# Rotated vel.
# [ 19.75509262  19.0717144   20.67724609]
# Found 1081667 stars.
# Rotated pos.
# Rotated vel.
# [ 20.13412285  19.44070625  21.10229874]
# Found 1120839 stars.
# Rotated pos.
# Rotated vel.
# [ 20.42412758  19.72184372  21.42675972]
# Found 1154417 stars.
# Rotated pos.
# Rotated vel.
# [ 20.81840324  20.10211563  21.86827469]
# Found 1194051 stars.
# Rotated pos.
# Rotated vel.
# [ 21.11937714  20.39230919  22.20462799]
# Found 1227647 stars.
# Rotated pos.
# Rotated vel.
# [ 21.42389488  20.68611908  22.54693604]
# Found 1255435 stars.
# Rotated pos.
# Rotated vel.
# [ 21.73373222  20.98360252  22.89403915]
# Found 1283929 stars.
# Rotated pos.
# Rotated vel.
# [ 22.153759    21.38641167  23.364851  ]
# Found 1315974 stars.
# Rotated pos.
# Rotated vel.
# [ 22.47373009  21.69274902  23.72468185]
# Found 1349298 stars.
# Rotated pos.
# Rotated vel.
# [ 22.7996521   22.0025444   24.08984756]
# Found 1373081 stars.
# Rotated pos.
# Rotated vel.
# [ 23.13161278  22.31706619  24.45867538]
# Found 1400280 stars.
# Rotated pos.
# Rotated vel.
# [ 23.46821594  22.63773918  24.8325634 ]
# Found 1416479 stars.
# Rotated pos.
# Rotated vel.
# [ 23.80860329  22.96368408  25.21352386]
# Found 1428816 stars.
# Rotated pos.
# Rotated vel.
# [ 24.15342522  23.29395103  25.60112953]
# Found 1445387 stars.
# Rotated pos.
# Rotated vel.
# [ 24.50271797  23.62892342  25.99520683]
# Found 1470007 stars.
# Rotated pos.
# Rotated vel.
# [ 24.85713387  23.96839905  26.39595032]
# Found 1484340 stars.
# Rotated pos.
# Rotated vel.
# [ 25.21674347  24.31293106  26.80324364]
# Found 1494084 stars.
# Rotated pos.
# Rotated vel.
# [ 25.45941925  24.54529381  27.07883453]
# Found 1509390 stars.
# Rotated pos.
# Rotated vel.
# [ 25.82858849  24.89687347  27.49774933]
# Found 1532350 stars.
# Rotated pos.
# Rotated vel.
# [ 26.2042942   25.2542057   27.92131042]
# Found 1524327 stars.
# Rotated pos.
# Rotated vel.
# [ 26.58517647  25.61821175  28.35095024]
# Found 1553881 stars.
# Rotated pos.
# Rotated vel.
# [ 26.97145081  25.98770905  28.78736305]
# Found 1562371 stars.
# Rotated pos.
# Rotated vel.
# [ 27.23214722  26.23708725  29.08192825]
# Found 1625123 stars.
# Rotated pos.
# Rotated vel.
# [ 27.62681198  26.61546135  29.52968025]
# Found 1597012 stars.
# Rotated pos.
# Rotated vel.
# [ 28.02821541  26.99830246  29.98339081]
# Found 1596516 stars.
# Rotated pos.
# Rotated vel.
# [ 28.29884148  27.25717163  30.28975487]
# Found 1611388 stars.
# Rotated pos.
# Rotated vel.
# [ 28.71037102  27.65019417  30.75450516]
# Found 1681756 stars.
# Rotated pos.
# Rotated vel.
# [ 29.12677383  28.04948807  31.22624779]
# Found 1636296 stars.
# Rotated pos.
# Rotated vel.
# [ 29.40730476  28.31895065  31.54471207]
# Found 1680675 stars.
# Rotated pos.
# Rotated vel.
# [ 29.83269691  28.72842789  32.02832794]
# Found 1689680 stars.
# Rotated pos.
# Rotated vel.
# [ 30.11922264  29.0051918   32.35468674]
# Found 1690508 stars.
# Rotated pos.
# Rotated vel.
# [ 30.55345726  29.42549706  32.85093689]
# Found 1709507 stars.
# Rotated pos.
# Rotated vel.
# [ 30.99422073  29.85132217  33.35467911]
# Found 1704816 stars.
# Rotated pos.
# Rotated vel.
# [ 31.29102707  30.13891983  33.69516754]
# Found 1717424 stars.
# Rotated pos.
# Rotated vel.
# [ 31.74212646  30.57429314  34.21273041]
# Found 1726323 stars.
# Rotated pos.
# Rotated vel.
# [ 32.04627228  30.8679924   34.56239319]
# Found 1736454 stars.
# Rotated pos.
# Rotated vel.
# [ 32.50867844  31.31370544  35.09283066]
# Found 1755643 stars.
# Rotated pos.
# Rotated vel.
# [ 32.82047653  31.61475182  35.45058823]
# Found 1755878 stars.
# Rotated pos.
# Rotated vel.
# [ 33.29346848  32.07149124  35.99433899]
# Found 1758643 stars.
# Rotated pos.
# Rotated vel.
# [ 33.61259842  32.37949753  36.36141205]
# Found 1769475 stars.
# Rotated pos.
# Rotated vel.
# [ 34.09642792  32.84707642  36.91917419]
# Found 1774142 stars.
# Rotated pos.
# Rotated vel.
# [ 34.42281723  33.16259384  37.29567337]
# Found 1783163 stars.
# Rotated pos.
# Rotated vel.
# 0.05386383515388214 2648 49161
