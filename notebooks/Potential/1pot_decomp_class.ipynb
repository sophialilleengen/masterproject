# %%
machine = 'mac'
machine = 'virgo'

# %%
if machine == 'magny':
    basedir = "/hits/universe/GigaGalaxy/level4_MHD/"
    filedir = "/home/extmilan/masterthesis/files/"
    plotdir = "/home/extmilan/masterthesis/plots/"
elif machine == 'mac': 
    basedir = "/Users/smilanov/Desktop/Auriga/level4/"
    filedir = "/Users/smilanov/Documents/masterthesis/auriga_files/files/"
    plotdir = "/Users/smilanov/Documents/masterthesis/auriga_files/plots/"
elif machine == 'virgo': 
    basedir = "/virgo/simulations/Auriga/level4_MHD/"
    filedir = "/u/milas/masterthesis/masterproject/files/"
    plotdir = "/u/milas/masterthesis/masterproject/plots/"
    
    
#file = filedir + 'potential_params_10000_with_initeqbestfit.txt'

#dopotfit = True

# %%
from galpy.potential import NFWPotential as NFWpot
from galpy.potential import HernquistPotential as HEpot
from galpy.potential import DoubleExponentialDiskPotential as DEpot
from galpy.potential import MiyamotoNagaiPotential as MNpot
from galpy.potential import MN3ExponentialDiskPotential as MN3pot
from galpy.potential import MWPotential2014
from galpy.potential import evaluatePotentials, MiyamotoNagaiPotential, NFWPotential, HernquistPotential


from galpy.potential import evaluateDensities, evaluatePotentials
from galpy.potential import plotDensities
from galpy.potential import plotRotcurve
from galpy.util import bovy_conversion

import emcee

import numpy as np

from scipy import optimize as opt
from scipy import integrate

from astropy import units

from IPython.display import display

import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

from mpl_toolkits.axes_grid1 import make_axes_locatable
from mpl_toolkits.mplot3d import Axes3D
import copy

from areposnap.gadget import gadget_readsnap
from areposnap.gadget_subfind import load_subfind

from auriga_basics import *
from auriga_functions import *
from decomposition import *


import datetime
import random

# %matplotlib inline

from matplotlib import colors
from matplotlib import rcParams 
rcParams['font.size'] = 16
rcParams['lines.linewidth'] = 1.5
rcParams['axes.linewidth'] = 1.5
rcParams['ytick.major.width'] = 1.5
rcParams['xtick.major.width'] = 1.5
rcParams['image.cmap'] = 'magma'

cmap = copy.copy(plt.cm.get_cmap(rcParams['image.cmap']))
cmap.set_bad((0,0,0))

# %% [markdown]
# Build the potential
# ---
# - Disk: Miyamoto Nagai (http://adsabs.harvard.edu/abs/1975PASJ...27..533M
# - Spheroid: Hernquist (http://adsabs.harvard.edu/abs/1990ApJ...356..359H)
# - Halo: NFW (http://iopscience.iop.org/article/10.1086/304888/pdf)
#
# $v_{circ} = \sqrt{R\frac{\partial\Phi}{\partial R}}$
#
# Miyamoto Nagai potential
# --
#
# $\Phi_{MN} (R,z) = -\frac{GM}{\sqrt{R^2 + \left(a + \sqrt{z^2 + b^2}\right)^2}}$
#
# $\rho_{MN} (R,z) = \frac{b^2M}{4\pi}
# \frac{aR^2 + \left(a + 3\sqrt{z^2 + b^2}\right)\left(a + \sqrt{z^2 + b^2}\right)^2}
# {\left[R^2 + \left(a + \sqrt{z^2 + b^2}\right)^2\right]^{5/2}\left(z^2 + b^2\right)^{3/2}}$
#
# $
# v_{circ_{MN}}(R,z)     = R \sqrt{
# \frac
# { GM }
# { \left(R^2 + \left(a + \sqrt{z^2+b^2}\right)^2\right)^{3/2} }
# }
# $
#
# Hernquist potential
# --
# $\Phi_H(r) = -\frac
# {GM}
# {r+a}
# $
#
# $\rho_H(r) = \frac{M}{2\pi}\frac{r}{a}\frac{1}{\left(r+a\right)^3}
# $
#
# $M_H(r) = M \frac{r^2}{(r+a)^2}$
#
# $v_{circ_H}(r) = \frac
# {\sqrt{GMr} }
# {r+a}
# = \sqrt{\frac{GM(<r)}{r}}
# $
#     last equation part only valid in spherical symmetric systems
#
# NFW potential
# --
#
# 1. fit MND and HB
# 2. calculate their circular velocities
# 3. calculate total velocity and get circular velocity of NFW by subtracting: $v_{circ_{NFW}} = \sqrt{v_{circ_{tot}}^2 - v_{circ_{MND}}^2 - v_{circ_{HB}}^2}$
# 4. setup galpy potential with fixed MND and HB with fitted vals and just fit NFW parameters to pot vals
# 5. (possible check: fit also v0 of NFW and compare to 'real' one)

# %%
#guess is the guess of the fit with 
# init values (earlier best fit at z = 0) # need to changge that for time evolution #actually shouldn't bother single element fit
a_MND_kpc   = 2.96507719743
b_MND_kpc   = 1.63627757204
a_HB_kpc    = 1.71545528287
a_NFWH_kpc  = 26.0152749345
v0_tot_kms  = 220.724646624
v0_MND_kms  = 105.005287928
v0_HB_kms   = 111.241910552
v0_NFWH_kms = 159.117869741
R0_kpc      = 8.02852213383


#guess_bulge = np.array([a_MND_kpc, b_MND_kpc, a_HB_fit, a_NFWH_kpc, v0_tot_kms, v0_MND_kms, v0_HB_fit, v0_NFWH_kms, R0_kpc])
#guess_halo = np.array([a_MND_kpc, b_MND_kpc, a_HB_kpc, a_NFWH_fit, v0_tot_kms, v0_MND_kms, v0_HB_kms, v0_NFWH_fit, R0_kpc])

#gal24 = decomposition(machine = machine, have_galpy_potential = False)

# %%
#rho_data, Rbins_data_kpc, zbins_data_kpc = gal24.voldens_disk_2d_data()
def fit_disk(x):
    a_MND_fit  = x[0]
    b_MND_fit  = x[1]
    v0_MND_fit = x[2]
    guess_disk = np.array([a_MND_fit, b_MND_fit, a_HB_kpc, a_NFWH_kpc, v0_tot_kms, v0_MND_fit, v0_HB_kms, v0_NFWH_kms, R0_kpc])
    gal24._get_galpy_parameters(inputdata = guess_disk, inputfile = None)
    gal24._setup_galpy_potential(use_masses=True, whole_potential = False)
    
    voldens_galpy, Rbins_gal_kpc, zbins_gal_kpc = gal24.voldens_disk_2d_galpy(use_masses = True)
    
    if np.array_equal(Rbins_gal_kpc, Rbins_data_kpc) * np.array_equal(zbins_gal_kpc, zbins_data_kpc):
        err = np.sum(((rho_data - voldens_galpy) / voldens_galpy)**2)
        return err
    else: 
        print('Check that you got the same R and z bins because the densities should be calculate dat the same spots.')
        return ValueError
    
    
#rho_spher_Msun_pc3, r_spher_mean_kpc = gal24.voldens_spher_data()
def fit_spher(x):
    a_HB_fit  = x[0]
    v0_HB_fit = x[1]
    guess_spher = np.array([a_MND_kpc, b_MND_kpc, a_HB_fit, a_NFWH_kpc, v0_tot_kms, v0_MND_kms, v0_HB_fit, v0_NFWH_kms, R0_kpc])
    gal24._get_galpy_parameters(inputdata = guess_spher, inputfile = None)
    gal24._setup_galpy_potential(use_masses=True, whole_potential = False)
    
    voldens_spher_galpy = gal24.voldens_spher_galpy(r_spher_mean_kpc, use_masses=True)
    
    err = np.sum(((rho_spher_Msun_pc3 - voldens_spher_galpy) / voldens_spher_galpy)**2)
    return err

#rho_halo_Msun_pc3, r_halo_mean_kpc = gal24.voldens_halo_data()
def fit_halo(x):
    a_NFWH_fit  = x[0]
    v0_NFWH_fit = x[1]
    guess_halo = np.array([a_MND_kpc, b_MND_kpc, a_HB_kpc, a_NFWH_fit, v0_tot_kms, v0_MND_kms, v0_HB_kms, v0_NFWH_fit, R0_kpc])
    gal24._get_galpy_parameters(inputdata = guess_halo, inputfile = None)
    gal24._setup_galpy_potential(use_masses=True, whole_potential = False)
    
    voldens_halo_galpy = gal24.voldens_halo_galpy(r_halo_mean_kpc, use_masses = True)
    
    err = np.sum(((rho_halo_Msun_pc3 - voldens_halo_galpy) / voldens_halo_galpy)**2)
    return err

# %% [markdown]
# lower_floor = 1e-3
# bounds_disk = ((lower_floor, 20.), # a MND_kpc
#          (lower_floor, 10.), # b_MND_kpc
#          (1., 250.)) #v0_MND_kms
#
# bounds_spher = ((lower_floor, 50.), # a MND_kpc
#          (1., 250.)) #v0_MND_kms
#
#
# bounds_halo = ((lower_floor, 100.), # a MND_kpc
#          (1., 350.)) #v0_MND_kms
#
#
# '''res_disk = opt.differential_evolution(
#             fit_disk,
#             bounds=bounds_disk,
#             #args=args,#, MND, HB, NFWH),
#             strategy='best1bin',
#             maxiter=1000,tol=0.01,atol=1e-7,
#             disp=True
#             )
# '''
#
# res_spher = opt.differential_evolution(
#             fit_spher,
#             bounds=bounds_spher,
#             #args=args,#, MND, HB, NFWH),
#             strategy='best1bin',
#             maxiter=50,tol=0.01,atol=1e-7,
#             disp=True
#             )
#
# print(res_spher)
# res_halo = opt.differential_evolution(
#             fit_halo,
#             bounds=bounds_halo,
#             #args=args,#, MND, HB, NFWH),
#             strategy='best1bin',
#             maxiter=1000,tol=0.01,atol=1e-7,
#             disp=True
#             )

# %%
import datetime
lower_floor = 1e-3
bounds_disk = ((lower_floor, 20.), # a MND_kpc
         (lower_floor, 10.), # b_MND_kpc
         (1., 250.)) #v0_MND_kms

bounds_spher = ((lower_floor, 50.), # a MND_kpc
         (1., 250.)) #v0_MND_kms


bounds_halo = ((lower_floor, 100.), # a MND_kpc
         (1., 350.)) #v0_MND_kms

a_MND_all = []
b_MND_all = []
v0_MND_all = []
a_HB_all = []
v0_HB_all = []
a_NFWH_all = []
v0_NFWH_all = []
v0_tot_all = []

for i in range(60,128,1):
    gal24 = decomposition(machine = machine, snapnr = i, have_galpy_potential = False)
    rho_data, Rbins_data_kpc, zbins_data_kpc = gal24.voldens_disk_2d_data()
    rho_spher_Msun_pc3, r_spher_mean_kpc = gal24.voldens_spher_data()
    rho_halo_Msun_pc3, r_halo_mean_kpc = gal24.voldens_halo_data()

    res_disk = opt.differential_evolution(
            fit_disk,
            bounds=bounds_disk,
            #args=args,#, MND, HB, NFWH),
            strategy='best1bin',
            maxiter=1000,tol=0.01,atol=1e-7,
            disp=True
            )
    
    a_MND_kpc_bestfit = res_disk.x[0]
    b_MND_kpc_bestfit = res_disk.x[1]
    v0_MND_kms_bestfit = res_disk.x[2]
    
    res_spher = opt.differential_evolution(
                fit_spher,
                bounds=bounds_spher,
                #args=args,#, MND, HB, NFWH),
                strategy='best1bin',
                maxiter=1000,tol=0.01,atol=1e-7,
                disp=True
                )

    a_HB_kpc_bestfit = res_spher.x[0]
    v0_HB_kms_bestfit = res_spher.x[1]
    
    res_halo = opt.differential_evolution(
                fit_halo,
                bounds=bounds_halo,
                #args=args,#, MND, HB, NFWH),
                strategy='best1bin',
                maxiter=1000,tol=0.01,atol=1e-7,
                disp=True
                )
    
    a_NFWH_kpc_bestfit = res_halo.x[0]
    v0_NFWH_kms_bestfit = res_halo.x[1]
    
    a_MND_all.append(a_MND_kpc_bestfit)
    b_MND_all.append(b_MND_kpc_bestfit)
    v0_MND_all.append(v0_MND_kms_bestfit)
    a_HB_all.append(a_HB_kpc_bestfit)
    v0_HB_all.append(v0_HB_kms_bestfit)
    a_NFWH_all.append(a_NFWH_kpc_bestfit)
    v0_NFWH_all.append(v0_NFWH_kms_bestfit)
    v0_tot = np.sqrt(v0_MND_kms_bestfit**2 + v0_HB_kms_bestfit**2 + v0_NFWH_kms_bestfit**2)
    v0_tot_all.append(v0_tot)
    print(datetime.datetime.now().time())
    print('Snap: {} \na_MND [kpc]: {:2f}\nb_MND [kpc]: {:2f}\na_HB [kpc]: {:2f}\na_NFWH [kpc]: {:2f}'.format(i, a_MND_kpc_bestfit, b_MND_kpc_bestfit, a_HB_kpc_bestfit, a_NFWH_kpc_bestfit))
    print('v0_MND [km/s]: {} \nv0_HB [km/s]: {:2f}\nv0_NFWH [km/s]: {:2f}\nv0_tot [km/s]: {:2f}'.format(v0_MND_kms_bestfit, v0_HB_kms_bestfit, v0_NFWH_kms_bestfit, v0_tot))

a_MND_all = np.array(a_MND_all)
b_MND_all = np.array(b_MND_all)
v0_MND_all = np.array(v0_MND_all)
a_HB_all = np.array(a_HB_all)
v0_HB_all = np.array(v0_HB_all)
a_NFWH_all = np.array(a_NFWH_all)
v0_NFWH_all = np.array(v0_NFWH_all)
v0_tot_all = np.array(v0_tot_all)

data = (a_MND_all, b_MND_all, a_HB_all, a_NFWH_all, v0_MND_all, v0_HB_all, v0_NFWH_all, v_tot_all)
header = 'a_MND_all [kpc], b_MND_all [kpc], a_HB_all [kpc], a_NFWH_all [kpc], v0_MND_all [km/s], v0_HB_all [km/s], v0_NFWH_all [km/s], v_tot_all [km/s]'
np.savetxt(filedir + 'potfitvals_nov18.txt', data, header =header, fmt = '%1.10f')
# Out:
# Load snapshot.
# level   : 4
# halo	: 24
# snapnr  : 60
# basedir : /virgo/simulations/Auriga/level4_MHD/
# halodir : /virgo/simulations/Auriga/level4_MHD/halo_24/
# snappath: /virgo/simulations/Auriga/level4_MHD/halo_24/output/
#
# Found 84249 stars.
# Rotated pos.
# Rotated vel.
#
# galrad  : 0.008027402311563491
# redshift: 2.1032696525957713
# time    : 0.32224076923625916
# center  : [ 0.  0.  0.]
#
# Carry out decomposition.
# computing star properties
# computing histograms
# Calculate disk indices.
# Calculate spheroid indices.
# Calculate halo indices.
# Load positions and masses of simulation data.
# computing star properties
# computing histograms
# Galpy potentials not initialized.
# Set plot options.
# differential_evolution step 1: f(x)= 92.2942
# differential_evolution step 2: f(x)= 91.6648
# differential_evolution step 3: f(x)= 88.6202
# differential_evolution step 4: f(x)= 88.6202
# differential_evolution step 5: f(x)= 88.489
# differential_evolution step 6: f(x)= 88.434
# differential_evolution step 7: f(x)= 88.4116
# differential_evolution step 8: f(x)= 88.4116
# differential_evolution step 9: f(x)= 88.4114
# differential_evolution step 10: f(x)= 88.4114
# differential_evolution step 1: f(x)= 92.8062
# differential_evolution step 2: f(x)= 92.8062
# differential_evolution step 3: f(x)= 84.3365
# differential_evolution step 4: f(x)= 80.645
# differential_evolution step 5: f(x)= 80.645
# differential_evolution step 6: f(x)= 80.4919
# differential_evolution step 7: f(x)= 80.4919
# differential_evolution step 8: f(x)= 80.4919
# differential_evolution step 9: f(x)= 80.4917
# differential_evolution step 10: f(x)= 80.4917
# differential_evolution step 11: f(x)= 80.4917
# differential_evolution step 12: f(x)= 80.4915
# differential_evolution step 1: f(x)= 7.77658
# differential_evolution step 2: f(x)= 7.49801
# differential_evolution step 3: f(x)= 6.18942
# differential_evolution step 4: f(x)= 6.12968
# differential_evolution step 5: f(x)= 5.95402
# differential_evolution step 6: f(x)= 5.95402
# differential_evolution step 7: f(x)= 5.95175
# differential_evolution step 8: f(x)= 5.90696
# differential_evolution step 9: f(x)= 5.89425
# differential_evolution step 10: f(x)= 5.89352
# differential_evolution step 11: f(x)= 5.89352
# differential_evolution step 12: f(x)= 5.89352
# 01:06:44.100483
# Snap: 60
# a_MND [kpc]: 2.569770
# b_MND [kpc]: 1.935214
# a_HB [kpc]: 1.504866
# a_NFWH [kpc]: 1.141417
# v0_MND [km/s]: 194.5236953904867
# v0_HB [km/s]: 17.242389
# v0_NFWH [km/s]: 235.240863
# v0_tot [km/s]: 305.736867
# Load snapshot.
# level   : 4
# halo	: 24
# snapnr  : 61
# basedir : /virgo/simulations/Auriga/level4_MHD/
# halodir : /virgo/simulations/Auriga/level4_MHD/halo_24/
# snappath: /virgo/simulations/Auriga/level4_MHD/halo_24/output/
#
# Found 103761 stars.
# Rotated pos.
# Rotated vel.
#
# galrad  : 0.008606187999248505
# redshift: 2.0020281392528516
# time    : 0.3331081367707903
# center  : [ 0.  0.  0.]
#
# Carry out decomposition.
# computing star properties
# computing histograms
# Calculate disk indices.
# Calculate spheroid indices.
# Calculate halo indices.
# Load positions and masses of simulation data.
# computing star properties
# computing histograms
# Galpy potentials not initialized.
# Set plot options.
# differential_evolution step 1: f(x)= 91.0356
# differential_evolution step 2: f(x)= 91.0356
# differential_evolution step 3: f(x)= 91.0356
# differential_evolution step 4: f(x)= 90.3228
# differential_evolution step 5: f(x)= 89.8145
# differential_evolution step 6: f(x)= 89.7867
# differential_evolution step 7: f(x)= 89.7867
# differential_evolution step 8: f(x)= 89.7864
# differential_evolution step 9: f(x)= 89.7864
# differential_evolution step 1: f(x)= 81.2505
# differential_evolution step 2: f(x)= 81.2505
# differential_evolution step 3: f(x)= 81.2505
# differential_evolution step 4: f(x)= 81.2505
# differential_evolution step 5: f(x)= 79.8865
# differential_evolution step 6: f(x)= 79.4569
# differential_evolution step 7: f(x)= 79.4295
# differential_evolution step 13: f(x)= 140.096
# differential_evolution step 14: f(x)= 140.031
# differential_evolution step 15: f(x)= 140.028
# differential_evolution step 1: f(x)= 25.3488
# differential_evolution step 2: f(x)= 25.3488
# differential_evolution step 3: f(x)= 25.3488
# differential_evolution step 4: f(x)= 25.3488
# differential_evolution step 5: f(x)= 25.3488
# differential_evolution step 6: f(x)= 25.3488
# differential_evolution step 7: f(x)= 25.3488
# differential_evolution step 8: f(x)= 25.3294
# differential_evolution step 9: f(x)= 25.3294
# differential_evolution step 10: f(x)= 25.3294
# differential_evolution step 11: f(x)= 25.3275
# differential_evolution step 12: f(x)= 25.3267
# differential_evolution step 1: f(x)= 4.1514
# differential_evolution step 2: f(x)= 4.14804
# differential_evolution step 3: f(x)= 4.14804
# differential_evolution step 4: f(x)= 3.29901
# differential_evolution step 5: f(x)= 3.21361
# differential_evolution step 6: f(x)= 3.21361
# differential_evolution step 7: f(x)= 3.21361
# differential_evolution step 8: f(x)= 3.21344
# differential_evolution step 9: f(x)= 3.21288
# 08:22:55.047294
# Snap: 74
# a_MND [kpc]: 0.115811
# b_MND [kpc]: 1.472227
# a_HB [kpc]: 1.269919
# a_NFWH [kpc]: 2.683510
# v0_MND [km/s]: 190.64361752820105
# v0_HB [km/s]: 79.251754
# v0_NFWH [km/s]: 226.670883
# v0_tot [km/s]: 306.603194
# Load snapshot.
# level   : 4
# halo	: 24
# snapnr  : 75
# basedir : /virgo/simulations/Auriga/level4_MHD/
# halodir : /virgo/simulations/Auriga/level4_MHD/halo_24/
# snappath: /virgo/simulations/Auriga/level4_MHD/halo_24/output/
#
# Found 788548 stars.
# Rotated pos.
# Rotated vel.
#
# galrad  : 0.014569315314292909
# redshift: 1.1141505637653806
# time    : 0.4730032085410998
# center  : [ 0.  0.  0.]
#
# Carry out decomposition.
# computing star properties
# computing histograms
# Calculate disk indices.
# Calculate spheroid indices.
# Calculate halo indices.
# Load positions and masses of simulation data.
# computing star properties
# computing histograms
# Galpy potentials not initialized.
# Set plot options.
# differential_evolution step 1: f(x)= 157.457
# differential_evolution step 2: f(x)= 157.457
# differential_evolution step 3: f(x)= 157.457
# differential_evolution step 4: f(x)= 157.457
# differential_evolution step 5: f(x)= 153.489
# differential_evolution step 6: f(x)= 151.513
# differential_evolution step 7: f(x)= 146.716
# differential_evolution step 8: f(x)= 145.256
# differential_evolution step 9: f(x)= 144.842
# differential_evolution step 10: f(x)= 144.814
# differential_evolution step 11: f(x)= 144.814
# differential_evolution step 12: f(x)= 144.814
# differential_evolution step 13: f(x)= 144.814
# differential_evolution step 14: f(x)= 144.814
# differential_evolution step 1: f(x)= 44.426
# differential_evolution step 2: f(x)= 44.426
# differential_evolution step 3: f(x)= 35.3119
# differential_evolution step 4: f(x)= 31.4593
# differential_evolution step 5: f(x)= 31.4275
# differential_evolution step 6: f(x)= 31.4275
# differential_evolution step 7: f(x)= 31.4275
# differential_evolution step 8: f(x)= 31.4275
# differential_evolution step 9: f(x)= 31.4261
# differential_evolution step 10: f(x)= 3.12477
# 13:24:32.817929
# Snap: 83
# a_MND [kpc]: 0.534178
# b_MND [kpc]: 1.544844
# a_HB [kpc]: 1.422120
# a_NFWH [kpc]: 3.134937
# v0_MND [km/s]: 76.84150214221006
# v0_HB [km/s]: 95.679356
# v0_NFWH [km/s]: 38.188162
# v0_tot [km/s]: 128.520392
# Load snapshot.
# level   : 4
# halo	: 24
# snapnr  : 84
# basedir : /virgo/simulations/Auriga/level4_MHD/
# halodir : /virgo/simulations/Auriga/level4_MHD/halo_24/
# snappath: /virgo/simulations/Auriga/level4_MHD/halo_24/output/
#
# Found 1021584 stars.
# Rotated pos.
# Rotated vel.
#
# galrad  : 0.01679195463657379
# redshift: 0.7910682489463392
# time    : 0.5583260161014446
# center  : [ 0.  0.  0.]
#
# Carry out decomposition.
# computing star properties
# computing histograms
# Calculate disk indices.
# Calculate spheroid indices.
# Calculate halo indices.
# Load positions and masses of simulation data.
# computing star properties
# computing histograms
# Galpy potentials not initialized.
# Set plot options.
# differential_evolution step 1: f(x)= 152.016
# differential_evolution step 2: f(x)= 143.85
# differential_evolution step 3: f(x)= 143.563
# differential_evolution step 4: f(x)= 143.563
# differential_evolution step 5: f(x)= 143.563
# differential_evolution step 6: f(x)= 142.921
# differential_evolution step 7: f(x)= 142.921
# differential_evolution step 8: f(x)= 142.885
# differential_evolution step 9: f(x)= 142.849
# differential_evolution step 10: f(x)= 142.849
# differential_evolution step 11: f(x)= 142.849
# differential_evolution step 1: f(x)= 27.7674
# differential_evolution step 2: f(x)= 27.7674
# differential_evolution step 3: f(x)= 27.7674
# differential_evolution step 4: f(x)= 27.7674
# differential_evolution step 5: f(x)= 27.5202
# differential_evolution step 6: f(x)= 27.3859
# differential_evolution step 7: f(x)= 27.3859
# differential_evolution step 8: f(x)= 27.3842
# differential_evolution step 9: f(x)= 27.3842
# differential_evolution step 1: f(x)= 3.39484
# differential_evolution step 2: f(x)= 3.3513
# differential_evolution step 3: f(x)= 3.3513
# differential_evolution step 4: f(x)= 3.3513
# differential_evolution step 5: f(x)= 3.33151
# differential_evolution step 6: f(x)= 3.32145
# differential_evolution step 7: f(x)= 3.31601
# differential_evolution step 8: f(x)= 3.31601
# differential_evolution step 9: f(x)= 3.31594
# differential_evolution step 10: f(x)= 3.31594
# 13:54:30.499911
# Snap: 84
# a_MND [kpc]: 0.681526
# b_MND [kpc]: 1.534803
# a_HB [kpc]: 1.435782
# a_NFWH [kpc]: 3.140364
# v0_MND [km/s]: 198.75960400430344
# v0_HB [km/s]: 142.318490
# v0_NFWH [km/s]: 167.032324
# v0_tot [km/s]: 296.073859
# Load snapshot.
# level   : 4
# halo	: 24
# snapnr  : 85
# basedir : /virgo/simulations/Auriga/level4_MHD/
# halodir : /virgo/simulations/Auriga/level4_MHD/halo_24/
# snappath: /virgo/simulations/Auriga/level4_MHD/halo_24/output/
#
# Found 1059935 stars.
# Rotated pos.
# Rotated vel.
#
# galrad  : 0.01698329746723175
# redshift: 0.7574413726158526
# time    : 0.5690090239036288
# center  : [ 0.  0.  0.]
#
# Carry out decomposition.
# computing star properties
# computing histograms
# Calculate disk indices.
# Calculate spheroid indices.
# Calculate halo indices.
# Load positions and masses of simulation data.
# computing star properties
# computing histograms
# Galpy potentials not initialized.
# Set plot options.
# differential_evolution step 1: f(x)= 276.083
# differential_evolution step 2: f(x)= 162.049
# differential_evolution step 3: f(x)= 151.936
# differential_evolution step 4: f(x)= 151.936
# differential_evolution step 5: f(x)= 151.61
# differential_evolution step 6: f(x)= 150.761
# differential_evolution step 7: f(x)= 150.761
# differential_evolution step 8: f(x)= 150.655
# differential_evolution step 9: f(x)= 150.484
# differential_evolution step 10: f(x)= 150.484
# differential_evolution step 11: f(x)= 150.46
# differential_evolution step 12: f(x)= 150.285
# differential_evolution step 13: f(x)= 150.223
# differential_evolution step 14: f(x)= 150.22
# differential_evolution step 1: f(x)= 31.5946
# differential_evolution step 2: f(x)= 31.5946
# differential_evolution step 3: f(x)= 31.5946
# differential_evolution step 4: f(x)= 31.5946
# differential_evolution step 5: f(x)= 31.5946
# differential_evolution step 6: f(x)= 31.5935
# differential_evolution step 7: f(x)= 31.5935
# differential_evolution step 8: f(x)= 31.5935
# differential_evolution step 9: f(x)= 31.592
# differential_evolution step 10: f(x)= 31.592
# differential_evolution step 1: f(x)= 3.61155
# differential_evolution step 2: f(x)= 3.38942
# differential_evolution step 3: f(x)= 3.38942
# differential_evolution step 4: f(x)= 3.38942
# differential_evolution step 5: f(x)= 3.38719
# differential_evolution step 6: f(x)= 3.38719
# differential_evolution step 7: f(x)= 3.38719
# differential_evolution step 8: f(x)= 3.38538
# differential_evolution step 9: f(x)= 3.3853
# 14:27:47.724873
# Snap: 85
# a_MND [kpc]: 0.905628
# b_MND [kpc]: 1.470607
# a_HB [kpc]: 1.516807
# a_NFWH [kpc]: 3.157144
# v0_MND [km/s]: 80.9548958808625
# v0_HB [km/s]: 164.893214
# v0_NFWH [km/s]: 53.163358
# v0_tot [km/s]: 191.232345
# Load snapshot.
# level   : 4
# halo	: 24
# snapnr  : 86
# basedir : /virgo/simulations/Auriga/level4_MHD/
# halodir : /virgo/simulations/Auriga/level4_MHD/halo_24/
# snappath: /virgo/simulations/Auriga/level4_MHD/halo_24/output/
#
# Found 1081667 stars.
# Rotated pos.
# Rotated vel.
#
# galrad  : 0.01714651584625244
# redshift: 0.7326361820223115
# time    : 0.5771552102951079
# center  : [ 0.  0.  0.]
#
# Carry out decomposition.
# computing star properties
# computing histograms
# Calculate disk indices.
# Calculate spheroid indices.
# Calculate halo indices.
# Load positions and masses of simulation data.
# computing star properties
# computing histograms
# Galpy potentials not initialized.
# Set plot options.
# differential_evolution step 1: f(x)= 166.883
# differential_evolution step 2: f(x)= 159.283
# differential_evolution step 3: f(x)= 159.283
# differential_evolution step 4: f(x)= 159.283
# differential_evolution step 5: f(x)= 159.283
# differential_evolution step 6: f(x)= 159.283
# differential_evolution step 7: f(x)= 156.739
# differential_evolution step 8: f(x)= 156.451
# differential_evolution step 9: f(x)= 156.451
# differential_evolution step 10: f(x)= 156.451
# differential_evolution step 11: f(x)= 156.406
# differential_evolution step 12: f(x)= 156.406
# differential_evolution step 13: f(x)= 156.397
# differential_evolution step 14: f(x)= 156.39
# differential_evolution step 1: f(x)= 36.4645
# differential_evolution step 2: f(x)= 27.2137
# differential_evolution step 3: f(x)= 27.2137
# differential_evolution step 4: f(x)= 27.2137
# differential_evolution step 5: f(x)= 27.1795
# differential_evolution step 6: f(x)= 27.1795
# differential_evolution step 7: f(x)= 27.158
# differential_evolution step 8: f(x)= 27.158
# differential_evolution step 9: f(x)= 181.907
# differential_evolution step 10: f(x)= 181.868
# differential_evolution step 1: f(x)= 31.0697
# differential_evolution step 2: f(x)= 31.0697
# differential_evolution step 3: f(x)= 31.0697
# differential_evolution step 4: f(x)= 31.0697
# differential_evolution step 5: f(x)= 31.0697
# differential_evolution step 6: f(x)= 31.0697
# differential_evolution step 7: f(x)= 31.0469
# differential_evolution step 8: f(x)= 30.9778
# differential_evolution step 9: f(x)= 30.9668
# differential_evolution step 1: f(x)= 4.37702
# differential_evolution step 2: f(x)= 3.36738
# differential_evolution step 3: f(x)= 3.35945
# differential_evolution step 4: f(x)= 3.33365
# differential_evolution step 5: f(x)= 3.33068
# differential_evolution step 6: f(x)= 3.33054
# differential_evolution step 7: f(x)= 3.33054
# differential_evolution step 8: f(x)= 3.33044
# 17:40:35.245107
# Snap: 91
# a_MND [kpc]: 1.839050
# b_MND [kpc]: 1.560407
# a_HB [kpc]: 1.618092
# a_NFWH [kpc]: 3.382435
# v0_MND [km/s]: 122.62891385314819
# v0_HB [km/s]: 10.227340
# v0_NFWH [km/s]: 178.240177
# v0_tot [km/s]: 216.591805
# Load snapshot.
# level   : 4
# halo	: 24
# snapnr  : 92
# basedir : /virgo/simulations/Auriga/level4_MHD/
# halodir : /virgo/simulations/Auriga/level4_MHD/halo_24/
# snappath: /virgo/simulations/Auriga/level4_MHD/halo_24/output/
#
# Found 1283929 stars.
# Rotated pos.
# Rotated vel.
#
# galrad  : 0.018386109173297884
# redshift: 0.5759808451078874
# time    : 0.6345254785958663
# center  : [ 0.  0.  0.]
#
# Carry out decomposition.
# computing star properties
# computing histograms
# Calculate disk indices.
# Calculate spheroid indices.
# Calculate halo indices.
# Load positions and masses of simulation data.
# computing star properties
# computing histograms
# Galpy potentials not initialized.
# Set plot options.
# differential_evolution step 1: f(x)= 236.772
# differential_evolution step 2: f(x)= 174.675
# differential_evolution step 3: f(x)= 174.675
# differential_evolution step 4: f(x)= 163.598
# differential_evolution step 5: f(x)= 162.318
# differential_evolution step 6: f(x)= 160.186
# differential_evolution step 7: f(x)= 159.257
# differential_evolution step 8: f(x)= 159.257
# differential_evolution step 9: f(x)= 159.257
# differential_evolution step 10: f(x)= 159.257
# differential_evolution step 11: f(x)= 159.257
# differential_evolution step 12: f(x)= 159.171
# differential_evolution step 13: f(x)= 159.171
# differential_evolution step 1: f(x)= 29.6724
# differential_evolution step 2: f(x)= 29.6724
# differential_evolution step 3: f(x)= 29.6724
# differential_evolution step 4: f(x)= 29.6373
# differential_evolution step 5: f(x)= 29.5342
# differential_evolution step 6: f(x)= 29.5342
# differential_evolution step 7: f(x)= 29.5342
# differential_evolution step 8: f(x)= 29.5227
# differential_evolution step 9: f(x)= 29.5002
# differential_evolution step 10: f(x)= 29.4993
# differential_evolution step 1: f(x)= 3.26271
# differential_evolution step 2: f(x)= 3.26271
# differential_evolution step 3: f(x)= 3.26271
# differential_evolution step 4: f(x)= 3.24855
# differential_evolution step 5: f(x)= 3.24855
# differential_evolution step 6: f(x)= 3.23835
# differential_evolution step 7: f(x)= 3.23835
# differential_evolution step 8: f(x)= 3.23818
# 18:10:39.848729
# Snap: 92
# a_MND [kpc]: 1.847602
# b_MND [kpc]: 1.370428
# a_HB [kpc]: 1.602055
# a_NFWH [kpc]: 3.442344
# v0_MND [km/s]: 184.80966944852818
# v0_HB [km/s]: 54.701934
# v0_NFWH [km/s]: 214.793472
# v0_tot [km/s]: 288.588203
# Load snapshot.
# level   : 4
# halo	: 24
# snapnr  : 93
# basedir : /virgo/simulations/Auriga/level4_MHD/
# halodir : /virgo/simulations/Auriga/level4_MHD/halo_24/
# snappath: /virgo/simulations/Auriga/level4_MHD/halo_24/output/
#
# Found 1315974 stars.
# Rotated pos.
# Rotated vel.
#
# galrad  : 0.01867956817150116
# redshift: 0.5463921831410221
# time    : 0.6466664866145445
# center  : [ 0.  0.  0.]
#
# Carry out decomposition.
# computing star properties
# computing histograms
# Calculate disk indices.
# Calculate spheroid indices.
# Calculate halo indices.
# Load positions and masses of simulation data.
# computing star properties
# computing histograms
# Galpy potentials not initialized.
# Set plot options.
# differential_evolution step 1: f(x)= 178.866
# differential_evolution step 2: f(x)= 167.961
# differential_evolution step 3: f(x)= 167.691
# differential_evolution step 4: f(x)= 167.691
# differential_evolution step 5: f(x)= 167.691
# differential_evolution step 6: f(x)= 167.691
# differential_evolution step 7: f(x)= 167.691
# differential_evolution step 8: f(x)= 166.746
# differential_evolution step 9: f(x)= 166.746
# differential_evolution step 10: f(x)= 166.698
# differential_evolution step 11: f(x)= 166.698
# differential_evolution step 12: f(x)= 166.698
# differential_evolution step 13: f(x)= 166.683
# differential_evolution step 1: f(x)= 31.1015
# differential_evolution step 2: f(x)= 31.1015
# differential_evolution step 3: f(x)= 31.1015
# differential_evolution step 4: f(x)= 31.1015
# differential_evolution step 5: f(x)= 31.0754
# differential_evolution step 6: f(x)= 31.0754
# differential_evolution step 7: f(x)= 31.0754
# differential_evolution step 8: f(x)= 31.0725
# differential_evolution step 9: f(x)= 31.0725
# differential_evolution step 1: f(x)= 3.39173
# differential_evolution step 2: f(x)= 3.39173
# differential_evolution step 3: f(x)= 3.36975
# differential_evolution step 4: f(x)= 3.36674
# differential_evolution step 5: f(x)= 3.36674
# differential_evolution step 6: f(x)= 3.36674
# differential_evolution step 7: f(x)= 3.36674
# differential_evolution step 8: f(x)= 3.36674
# differential_evolution step 5: f(x)= 29.6235
# differential_evolution step 6: f(x)= 29.6235
# differential_evolution step 7: f(x)= 29.6235
# differential_evolution step 8: f(x)= 29.6235
# differential_evolution step 9: f(x)= 29.6235
# differential_evolution step 10: f(x)= 29.6235
# differential_evolution step 11: f(x)= 29.6235
# differential_evolution step 1: f(x)= 5.10374
# differential_evolution step 2: f(x)= 3.74066
# differential_evolution step 3: f(x)= 3.74066
# differential_evolution step 4: f(x)= 3.73939
# differential_evolution step 5: f(x)= 3.73679
# differential_evolution step 6: f(x)= 3.73679
# differential_evolution step 7: f(x)= 3.73665
# differential_evolution step 8: f(x)= 3.73664
# 10:17:22.726395
# Snap: 123
# a_MND [kpc]: 5.167591
# b_MND [kpc]: 1.974512
# a_HB [kpc]: 1.909142
# a_NFWH [kpc]: 4.253454
# v0_MND [km/s]: 188.95936137600648
# v0_HB [km/s]: 38.841591
# v0_NFWH [km/s]: 157.915791
# v0_tot [km/s]: 249.302439
# Load snapshot.
# level   : 4
# halo	: 24
# snapnr  : 124
# basedir : /virgo/simulations/Auriga/level4_MHD/
# halodir : /virgo/simulations/Auriga/level4_MHD/halo_24/
# snappath: /virgo/simulations/Auriga/level4_MHD/halo_24/output/
#
# Found 1758643 stars.
# Rotated pos.
# Rotated vel.
#
# galrad  : 0.02354053109884262
# redshift: 0.0337243718735154
# time    : 0.9673758568617342
# center  : [ 0.  0.  0.]
#
# Carry out decomposition.
# computing star properties
# computing histograms
# Calculate disk indices.
# Calculate spheroid indices.
# Calculate halo indices.
# Load positions and masses of simulation data.
# computing star properties
# computing histograms
# Galpy potentials not initialized.
# Set plot options.
# differential_evolution step 1: f(x)= 268.17
# differential_evolution step 2: f(x)= 232.532
# differential_evolution step 3: f(x)= 226.367
# differential_evolution step 4: f(x)= 225.75
# differential_evolution step 5: f(x)= 223.771
# differential_evolution step 6: f(x)= 222.692
# differential_evolution step 7: f(x)= 222.427
# differential_evolution step 8: f(x)= 222.427
# differential_evolution step 9: f(x)= 222.237
# differential_evolution step 1: f(x)= 37.6982
# differential_evolution step 2: f(x)= 31.4034
# differential_evolution step 5: f(x)= 29.8833
# differential_evolution step 6: f(x)= 29.7973
# differential_evolution step 7: f(x)= 29.7973
# differential_evolution step 8: f(x)= 29.7973
# differential_evolution step 9: f(x)= 29.7971
# differential_evolution step 1: f(x)= 3.68031
# differential_evolution step 2: f(x)= 3.68031
# differential_evolution step 3: f(x)= 3.68007
# differential_evolution step 4: f(x)= 3.67138
# differential_evolution step 5: f(x)= 3.66981
# differential_evolution step 6: f(x)= 3.66981
# differential_evolution step 7: f(x)= 3.66981
# differential_evolution step 8: f(x)= 3.6698
# 11:10:01.153881
# Snap: 125
# a_MND [kpc]: 5.148388
# b_MND [kpc]: 2.025134
# a_HB [kpc]: 1.934802
# a_NFWH [kpc]: 4.350346
# v0_MND [km/s]: 177.94512521399628
# v0_HB [km/s]: 77.075728
# v0_NFWH [km/s]: 110.915277
# v0_tot [km/s]: 223.399494
# Load snapshot.
# level   : 4
# halo	: 24
# snapnr  : 126
# basedir : /virgo/simulations/Auriga/level4_MHD/
# halodir : /virgo/simulations/Auriga/level4_MHD/halo_24/
# snappath: /virgo/simulations/Auriga/level4_MHD/halo_24/output/
#
# Found 1774142 stars.
# Rotated pos.
# Rotated vel.
#
# galrad  : 0.023996514081954957
# redshift: 0.009521666967944764
# time    : 0.99056814006128
# center  : [ 0.  0.  0.]
#
# Carry out decomposition.
# computing star properties
# computing histograms
# Calculate disk indices.
# Calculate spheroid indices.
# Calculate halo indices.
# Load positions and masses of simulation data.
# computing star properties
# computing histograms
# Galpy potentials not initialized.
# Set plot options.
# differential_evolution step 1: f(x)= 240.252
# differential_evolution step 2: f(x)= 240.252
# differential_evolution step 3: f(x)= 240.252
# differential_evolution step 1: f(x)= 29.5825
# differential_evolution step 2: f(x)= 29.5825
# differential_evolution step 3: f(x)= 29.5825
# differential_evolution step 4: f(x)= 29.5654
# differential_evolution step 5: f(x)= 29.5654
# differential_evolution step 6: f(x)= 29.5441
# differential_evolution step 7: f(x)= 29.5346
# differential_evolution step 8: f(x)= 29.5346
# differential_evolution step 1: f(x)= 4.63819
# differential_evolution step 2: f(x)= 3.6689
# differential_evolution step 3: f(x)= 3.6689
# differential_evolution step 4: f(x)= 3.6689
# differential_evolution step 5: f(x)= 3.66487
# differential_evolution step 6: f(x)= 3.66406
# differential_evolution step 7: f(x)= 3.66301
# differential_evolution step 8: f(x)= 3.66301
# differential_evolution step 9: f(x)= 3.66301
# differential_evolution step 10: f(x)= 3.66271
# 12:08:39.537355
# Snap: 127
# a_MND [kpc]: 5.181612
# b_MND [kpc]: 2.006359
# a_HB [kpc]: 1.948955
# a_NFWH [kpc]: 4.410234
# v0_MND [km/s]: 121.07379884957393
# v0_HB [km/s]: 10.118379
# v0_NFWH [km/s]: 40.112988
# v0_tot [km/s]: 127.946466
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /u/milas/conda-envs/auriga/lib/python3.6/site-packages/numpy/lib/npyio.py in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments)
#    1253                 try:
# -> 1254                     fh.write(asbytes(format % tuple(row) + newline))
#    1255                 except TypeError:
#
# TypeError: only length-1 arrays can be converted to Python scalars
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-751021eef9b4> in <module>()
#      88 data = (a_MND_all, b_MND_all, a_HB_all, a_NFWH_all, v0_MND_all, v0_HB_all, v0_NFWH_all, v_tot_all)
#      89 header = 'a_MND_all [kpc], b_MND_all [kpc], a_HB_all [kpc], a_NFWH_all [kpc], v0_MND_all [km/s], v0_HB_all [km/s], v0_NFWH_all [km/s], v_tot_all [km/s]'
# ---> 90 np.savetxt(filedir + 'potfitvals_nov18.txt', data, header =header, fmt = '%1.10f')
#
# /u/milas/conda-envs/auriga/lib/python3.6/site-packages/numpy/lib/npyio.py in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments)
#    1256                     raise TypeError("Mismatch between array dtype ('%s') and "
#    1257                                     "format specifier ('%s')"
# -> 1258                                     % (str(X.dtype), format))
#    1259         if len(footer) > 0:
#    1260             footer = footer.replace('\n', '\n' + comments)
#
# TypeError: Mismatch between array dtype ('object') and format specifier ('%1.10f')

# %%
data = (a_MND_all, b_MND_all, a_HB_all, a_NFWH_all, v0_MND_all, v0_HB_all, v0_NFWH_all)
header = 'a_MND_all [kpc], b_MND_all [kpc], a_HB_all [kpc], a_NFWH_all [kpc], v0_MND_all [km/s], v0_HB_all [km/s], v0_NFWH_all [km/s]'
np.savetxt(filedir + 'potfitvals_nov18.txt', data, header =header, fmt = '%1.10f')

# %%
data
# Out:
# (array([  2.56977032e+00,   1.85254982e+00,   1.43903390e+00,
#           8.40252024e-01,   1.00000000e-03,   1.28071790e+00,
#           9.56528184e-01,   7.85182328e-02,   1.99380766e-02,
#           1.06458774e-02,   2.51186256e-01,   1.12036831e-01,
#           1.01981330e-01,   1.07860635e+00,   1.15810600e-01,
#           1.88811063e-01,   3.21017584e-02,   3.21551254e-02,
#           3.19335789e-02,   4.26620789e-01,   3.74678852e-01,
#           3.63959782e-01,   7.51264453e-01,   5.34177735e-01,
#           6.81525806e-01,   9.05628178e-01,   9.28105353e-01,
#           9.84777648e-01,   1.19667409e+00,   1.44334286e+00,
#           1.69154580e+00,   1.83904974e+00,   1.84760159e+00,
#           1.97703902e+00,   2.21791293e+00,   2.39467781e+00,
#           2.63728417e+00,   2.79489075e+00,   2.96418486e+00,
#           2.99085198e+00,   3.15799649e+00,   3.13137785e+00,
#           3.24924426e+00,   3.32174703e+00,   3.33072767e+00,
#           3.22628257e+00,   3.51448823e+00,   3.70547665e+00,
#           4.24175890e+00,   3.81427788e+00,   3.50204255e+00,
#           3.73741325e+00,   3.60611385e+00,   4.05348017e+00,
#           4.10444252e+00,   4.50179780e+00,   4.43981069e+00,
#           4.54228126e+00,   4.64266970e+00,   4.77576695e+00,
#           4.91558080e+00,   4.96046537e+00,   5.30236721e+00,
#           5.16759086e+00,   5.05011746e+00,   5.14838834e+00,
#           4.96753134e+00,   5.18161158e+00]),
#  array([ 1.93521362,  2.16491788,  1.74327878,  2.12492843,  2.42914843,
#          2.28148587,  2.01548363,  1.35528042,  1.28126753,  1.17376678,
#          1.67178326,  1.6258899 ,  1.63077227,  1.80321583,  1.47222664,
#          1.85910386,  1.2389171 ,  1.30405974,  1.34196857,  1.68147373,
#          1.61669892,  1.68869788,  1.63906829,  1.54484405,  1.53480277,
#          1.47060746,  1.4063775 ,  1.473394  ,  1.38243601,  1.40364826,
#          1.38714648,  1.56040654,  1.37042812,  1.50448225,  1.47404426,
#          1.38161128,  1.59018927,  1.36721171,  1.52696939,  1.38061796,
#          1.58797984,  1.56060821,  1.43828688,  1.61729697,  1.86697945,
#          1.89485574,  1.69494635,  1.73329352,  1.59749431,  2.06877985,
#          1.73154514,  1.84871674,  2.97705671,  1.95365389,  1.84824969,
#          2.00875968,  1.79444278,  2.01064406,  1.98209145,  1.92839772,
#          2.04515913,  1.92518846,  1.92133064,  1.97451189,  1.97067452,
#          2.02513399,  2.03042058,  2.006359  ]),
#  array([ 1.50486562,  1.60104804,  1.41075066,  1.55918908,  2.41430205,
#          1.62464699,  1.49301693,  1.61399058,  1.54674403,  1.38716333,
#          1.28748299,  1.35534722,  1.36302472,  1.88763263,  1.26991908,
#          1.32538425,  1.45194405,  1.39681345,  1.37504139,  1.27967516,
#          1.32937309,  1.36194192,  1.40812839,  1.42211994,  1.43578196,
#          1.51680669,  1.46681562,  1.53886169,  1.57320473,  1.57382262,
#          1.60300661,  1.61809182,  1.60205519,  1.64682433,  1.67090615,
#          1.71713794,  1.73022606,  1.74344962,  1.74810765,  1.75804158,
#          1.7632832 ,  1.77151721,  1.76506715,  1.7869474 ,  1.82872736,
#          1.78712695,  1.79467579,  1.78954511,  2.09503237,  1.86751865,
#          1.85484375,  1.88637889,  1.92982927,  1.91620144,  1.95409745,
#          2.08303072,  2.04466687,  2.03132071,  1.96121487,  2.01090425,
#          1.9237133 ,  1.9045929 ,  1.92183586,  1.90914208,  1.90036976,
#          1.93480241,  1.93652848,  1.94895548]),
#  array([ 1.14141677,  1.0111665 ,  1.27656401,  1.38738985,  1.14171093,
#          1.5975244 ,  1.82856142,  1.86445702,  1.8660113 ,  1.9864305 ,
#          2.11265095,  2.27494643,  2.31665855,  1.96423803,  2.68351028,
#          2.72867147,  2.81771693,  2.85889875,  2.88513071,  2.95793343,
#          2.98294801,  3.0043315 ,  3.06229664,  3.1349366 ,  3.14036361,
#          3.15714432,  3.23751644,  3.25139424,  3.28057974,  3.31743342,
#          3.33301853,  3.38243478,  3.44234417,  3.47454421,  3.53065577,
#          3.52240235,  3.59644038,  3.66076418,  3.73092543,  3.79343802,
#          3.84856504,  3.91107674,  3.93417431,  3.91131164,  3.9203686 ,
#          3.9561129 ,  3.98153038,  3.97657062,  3.94611866,  4.06934268,
#          4.09523275,  4.13165639,  4.11211856,  4.145316  ,  4.1617844 ,
#          4.17488296,  4.19825666,  4.18590091,  4.20827478,  4.20255887,
#          4.18371462,  4.18572274,  4.22126979,  4.25345376,  4.30123587,
#          4.35034645,  4.40894056,  4.41023352]),
#  array([ 194.52369539,  102.42879884,  145.64623717,   20.59636108,
#          188.77992092,  129.02083446,  243.46421155,  174.95270967,
#           90.83681791,  130.88863342,   78.6350031 ,  201.62602596,
#          142.14076324,   50.30451862,  190.64361753,   52.23883247,
#           95.86322387,  238.55696509,  213.1616595 ,    5.01629414,
#          199.57812053,  117.3465854 ,  225.21409002,   76.84150214,
#          198.759604  ,   80.95489588,  161.60826187,  217.72829007,
#          162.31169564,   90.47901975,   20.42926132,  122.62891385,
#          184.80966945,  239.43501842,   94.56402507,   37.34611278,
#           71.53334156,   90.9805608 ,  101.57076398,   44.43973822,
#          240.47792736,   28.95537392,  116.10434434,   46.0398531 ,
#          180.96567039,  162.95680215,  203.02742072,   88.40269739,
#           66.03977268,   48.06074822,  126.4615424 ,  110.19532829,
#           78.51452428,   36.89452676,   27.4202716 ,   15.02303399,
#           29.6104576 ,  128.53724149,  104.29632531,  124.21516706,
#           92.91761773,  197.23717105,   85.08218717,  188.95936138,
#          208.29328924,  177.94512521,  133.23865628,  121.07379885]),
#  array([  17.24238917,  137.82963585,  116.80539617,  116.2240337 ,
#          243.95584339,   53.4143356 ,   81.57272878,  113.31331908,
#          136.66237747,   75.59752496,  201.89887728,   61.75660922,
#          249.57283673,   23.93617583,   79.25175405,  124.10249368,
#          152.20774035,  179.59872289,   85.41219236,   50.5721549 ,
#          240.09753217,  112.60508757,   51.5432534 ,   95.67935573,
#          142.31848985,  164.89321366,  102.58481184,  107.54263479,
#          152.1176584 ,  133.38746188,  104.83212182,   10.2273401 ,
#           54.70193448,  144.18603421,   38.31077443,   44.50151584,
#          244.73123821,   56.51072784,   61.52986369,   82.08147378,
#          138.60685463,    7.90224598,  153.02187396,  160.7912206 ,
#          175.32154542,  208.25093573,  180.72512365,   19.91984362,
#          171.68783596,   90.74227591,  166.57557015,  173.60649902,
#          220.52361167,   70.16742215,   16.78062872,   33.63895558,
#          150.1869393 ,   37.82815884,    5.32795392,  130.30979054,
#          176.74184975,   19.00123931,   84.04994577,   38.8415905 ,
#          166.74848466,   77.07572816,  177.18667777,   10.11837899]),
#  array([ 235.24086296,  246.39519988,   87.49662996,  161.46682037,
#          179.88018501,   87.56190468,  209.69732691,  128.44535444,
#          156.03041528,   56.90851011,  144.76701304,   98.02659188,
#          146.27614084,   24.24774407,  226.67088254,  118.88903497,
#          235.24979087,  285.49778094,  308.56128432,  137.10167031,
#           75.22173508,  289.70422454,  217.28200177,   38.18816153,
#          167.03232392,   53.16335797,  208.62761615,  159.88889926,
#          244.99310541,  342.06557451,   88.68751306,  178.24017745,
#          214.79347178,  276.4617686 ,  225.26624519,  116.52168949,
#           94.53973112,  306.16431243,  290.94401895,   23.37355925,
#          280.7632348 ,   95.97051803,  329.1995494 ,  231.65174036,
#          119.74353682,   41.60860214,   68.21760168,  149.01870211,
#          217.38753076,   78.6233135 ,  167.12936225,  200.2569279 ,
#          182.14571974,  302.40343378,  230.45919304,  315.23899742,
#          235.1382973 ,   33.08158221,  294.12498685,   57.3989255 ,
#          245.99161554,  278.49098517,  106.6226266 ,  157.91579055,
#          288.12379711,  110.91527684,  295.17080561,   40.11298805]))

# %%
voldens_galpy, Rbins, zbins = gal24.voldens_disk_2d_galpy()

# %%
rho, Rbins_data, zbins_data = gal24.voldens_disk_2d_data()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-0470458e19e3> in <module>()
# ----> 1 rho, Rbins_data, zbins_data = gal24.voldens_disk_2d_data()
#
# /freya/u/milas/masterthesis/masterproject/notebooks/decomposition.py in voldens_disk_2d_data(self, dR_kpc, dz_kpc)
#     578                 for i in range(len(zbins)):
#     579                         for j in range(len(Rbins)):
# --> 580                                 inbin = (Rbins[j] <= self.R_disk_kpc[indisk]) & (self.R_disk_kpc[indisk] < (Rbins[j] + dR_kpc)) & (zbins[i] <= self.z_disk_kpc[indisk]) & (self.z_disk_kpc[indisk] < (zbins[i] + dz_kpc))
#     581                                 mbins[i,j] = np.sum(self.disk_masses_10msun[inbin])
#     582                                 volbins[i,j] = np.pi * dz_kpc * (2. * Rbins[j] * dR_kpc + dR_kpc**2)
#
# KeyboardInterrupt:

# %%
plt.imshow(voldens_galpy, norm = colors.LogNorm(), origin = 'lower')#, cmap = plt.cm.magma)
plt.show()
plt.contourf(Rbins, zbins, voldens_galpy,  norm = colors.LogNorm())
plt.show()

# %%
plt.imshow(rho, norm = colors.LogNorm(), origin = 'lower')#, cmap = plt.cm.magma)
plt.show()
plt.contourf(Rbins_data, zbins_data, rho,  norm = colors.LogNorm())
plt.show()

# %%
#calculate density of disk
gal24 = decomposition(machine = machine)
gal24_z_kpc = gal24.z_disk_kpc
z_median = np.median(np.abs(gal24_z_kpc))

# %%
disk_dens_data = gal24.voldens_disk_data(N = 25, z_kpc = 0.5, R_kpc = None)

# %%
plt.plot(disk_dens_data[0], disk_dens_data[1])

# %%
gal24.s.calc_sf_indizes(gal24.sf)

# %%
def voldens_galpy(xdata, a_MND_kpc, b_MND_kpc):
    fix_z = True 
    fix_R = False 
    use_masses = True 
    use_n = False    
    R_kpc = xdata[0]
    z_kpc = xdata[1]
    mass_10Msun = xdata[2]
    disk = MiyamotoNagaiPotential(amp = mass_10Msun *1e10 *u.Msun, a=a_MND_kpc * u.kpc, b=b_MND_kpc * u.kpc)
    if fix_z == True:
        voldens_bestfit = np.zeros(len(R_kpc))
        if use_masses == True:
            for i, item in enumerate(R_kpc):
                voldens_bestfit[i] = disk.dens(item * u.kpc, z_kpc * u.kpc) 
        elif use_n == True:
            for i, item in enumerate(R_kpc):
                item_galpy = item / self.R0_kpc
                z_fix_galpy = z_kpc / self.R0_kpc
                voldens_bestfit[i] = self.disk.dens(item_galpy, z_fix_galpy) * bovy_conversion.dens_in_msolpc3(self.v0_tot_kms, self.R0_kpc)

    elif fix_R == True:
        voldens_bestfit = np.zeros(len(z_kpc))
        if use_masses == True:
            for i, item in enumerate(z_kpc):
                voldens_bestfit[i] = self.disk.dens(R_kpc * u.kpc, item * u.kpc) 
        elif use_n == True:
            for i, item in enumerate(z_kpc):
                item_galpy = item / self.R0_kpc
                R_fix_galpy = R_kpc / self.R0_kpc
                voldens_bestfit[i] = self.disk.dens(R_fix_galpy, item_galpy) * bovy_conversion.dens_in_msolpc3(self.v0_tot_kms, self.R0_kpc)

    return(voldens_bestfit)

# %%
z_median

# %%
disk_mass_10_Msun = np.sum(gal24.s.mass[gal24.i_disk][gal24.i_r_in])
xdata = np.array([disk_dens_data[1], 0., disk_mass_10_Msun])
rhodata = disk_dens_data[0]
plt.plot(disk_dens_data[1], disk_dens_data[0])
bounds = ([0., 0.],[np.inf, np.inf])
popt, pcov = opt.curve_fit(voldens_galpy, xdata, rhodata, bounds=bounds)

# %%
MNdisk_bestfit = MiyamotoNagaiPotential(amp = disk_mass_10_Msun * 1e10 * u.Msun, a=popt[0]*u.kpc, b=popt[1]*u.kpc)
MNdisk_dens_bestfit = MNdisk_bestfit.dens(disk_dens_data[1]*u.kpc, 0.*u.kpc)
plt.plot(disk_dens_data[1], disk_dens_data[0])

plt.plot(disk_dens_data[1], MNdisk_dens_bestfit)

# %%
opt.curve_fit?

# %%
MiyamotoNagaiPotential?

# %%
popt

# %%
### fit disk

# try to integrate numerically for poisson process
# take eq 2.69b (w/o mass) B&T08
# if that does not work fit to binned densities


## PART FOR THE LIKELIHOOD
Rmin_kpc = 1.
Rmax_kpc = 10.

def rho_MND(R_kpc, z_kpc, phi, a_kpc = 5., b_kpc = 1., specific = True, mass_10Msun = None):
    """
    INPUT:
        R_kpc, z_kpc: 
    """
    #a_kpc = args[0]
    #b_kpc = args[1]
    if specific == True:
        first_fac_kpc2 = b_kpc**2 / (4. * np.pi)
    else:
        first_fac_kpc2 = (mass_10Msun * b_kpc**2) / (4. * np.pi) # * 10^10M_sun
    bzsqrt_kpc = np.sqrt(z_kpc**2 + b_kpc**2)
    abz_sqrt_kpc = (a_kpc + bzsqrt_kpc)
    numerator_kpc3 = a_kpc * R_kpc**2 + (a_kpc + 3. * bzsqrt_kpc) * abz_sqrt_kpc**2
    denominator_kpc8 = (R_kpc**2 + abz_sqrt_kpc**2)**(5./2.) * bzsqrt_kpc**3
    rho_kpc_3 = first_fac_kpc2 * numerator_kpc3 / denominator_kpc8 # * 10^10 M_sun if not specific density
    return (rho_kpc_3)

'''    
def prob_MND(Rs, zs, a_kpc, b_kpc, Rmin_kpc, Rmax_kpc):
    res, res_err = integrate.tplquad(rho_MND, 0., 2. * np.pi, lambda phi: -np.inf, lambda phi: np.inf,
                  lambda phi, z_kpc: Rmin_kpc, lambda phi, z_kpc: Rmax_kpc, args = (a_kpc, b_kpc))
    rho = rho_MND(Rs, zs, a_kpc, b_kpc)
    p = rho / res
    return(p)

def likelihood_MND(Rs, zs, a_kpc, b_kpc, Rmin_kpc, Rmax_kpc):
    p = prob_MND(Rs, zs, a_kpc, b_kpc, Rmin_kpc, Rmax_kpc)
    logL = np.sum(np.log10(p))
    return logL

#_____function for scipy.differential_evolution that sums the relative error squares_____
def log_MND_scipydifferentialevolution(x, *args):
    
    # read fitting parameters:
    a_MND_kpc  = x[0]
    b_MND_kpc  = x[1]
    
    # read data:
    R_kpc_data    = args[0]
    z_kpc_data    = args[1]
    _REFR0_kpc    = args[2]
    Rmin_kpc      = args[3]
    Rmax_kpc      = args[4]
    
    logL_MND = likelihood_MND(R_kpc_data, z_kpc_data, a_MND_kpc, b_MND_kpc, Rmin_kpc, Rmax_kpc)
    #print(a_MND_kpc)
    #print(logL_MND)
    return (logL_MND)
'''
'''
def fit_MND(R_kpc_data, z_kpc_data, _REFR0_kpc = 8., Rmin_kpc = 1., Rmax_kpc = 10.):
    lower_floor = 1e-3
    bounds = ((lower_floor, 50.),  # a_MND
              (lower_floor, 10.))  # b_MND
              
    #fitting:
    res = opt.differential_evolution(
                log_MND_scipydifferentialevolution,
                bounds = bounds,
                args = (R_kpc_data, z_kpc_data, _REFR0_kpc, Rmin_kpc, Rmax_kpc),
                strategy = 'best1bin',
                maxiter = 1000, tol=0.01, atol=1e-7,
                disp = False
                )

    a_MND_kpc_bestfit  = res.x[0]
    b_MND_kpc_bestfit  = res.x[1]
    return(a_MND_kpc_bestfit, b_MND_kpc_bestfit)
'''

## PART FOR THE FIT TO THE DENSITY
def disk_dens(R_kpc, z_kpc, dR_kpc, dz_kpc, M_10Msun): 
    
    Rmin_kpc, Rmax_kpc = np.min(R_kpc), np.max(R_kpc)
    zmin_kpc, zmax_kpc = np.min(z_kpc), np.max(z_kpc)
    
    Rbins, zbins = np.arange(Rmin_kpc, Rmax_kpc, dR_kpc), np.arange(zmin_kpc, zmax_kpc, dz_kpc)
    mbins, volbins = np.zeros((len(zbins), len(Rbins))), np.zeros((len(zbins), len(Rbins))) 
    for i in range(len(zbins)):
        for j in range(len(Rbins)):
            inbin = (Rbins[j] <= R_kpc) & (R_kpc < (Rbins[j] + dR_kpc)) & (zbins[i] <= z_kpc) & (z_kpc < (zbins[i] + dz_kpc))
            mbins[i,j] = np.sum(M_10Msun[inbin])
            volbins[i,j] = np.pi * dz_kpc * (2. * Rbins[j] * dR_kpc + dR_kpc**2)
       
    rho = mbins / volbins
    return(rho, Rbins, zbins)    

def MNdens(x, a_kpc, b_kpc):
    '''
    INPUT: 
        x: R_kpc, z_kpc, Mass_tot
    '''
    R_kpc, z_kpc, mass_10Msun = x[0], x[1], x[2]
    first_fac_kpc2 = (mass_10Msun * b_kpc**2) / (4. * np.pi) # * 10^10M_sun
    bzsqrt_kpc = np.sqrt(z_kpc**2 + b_kpc**2)
    abz_sqrt_kpc = (a_kpc + bzsqrt_kpc)
    numerator_kpc3 = a_kpc * R_kpc**2 + (a_kpc + 3. * bzsqrt_kpc) * abz_sqrt_kpc**2
    denominator_kpc8 = (R_kpc**2 + abz_sqrt_kpc**2)**(5./2.) * bzsqrt_kpc**3
    rho_kpc_3 = first_fac_kpc2 * numerator_kpc3 / denominator_kpc8 # * 10^10 M_sun if not specific density
    return(rho_kpc_3)


def fit_dens_MND(R_kpc, z_kpc, dR_kpc, dz_kpc, M_tot_disk_stars_10Msun, M_diskstars_10Msun):
    rho_data, R_data, z_data = disk_dens(R_kpc, z_kpc, dR_kpc, dz_kpc, M_diskstars_10Msun)
    
    side_x = R_data
    side_y = z_data
    X1, X2 = np.meshgrid(side_x, side_y)
    size = X1.shape
    x1_1d = X1.reshape((1, np.prod(size)))
    x2_1d = X2.reshape((1, np.prod(size)))
    size2 = x1_1d.shape
    x3_1d = np.repeat(M_tot_disk_stars_10Msun, size2[1])
    x3_1d = x3_1d.reshape((size2))
    xdata = np.vstack((x1_1d, x2_1d, x3_1d))
    z = rho_data
    Z = z.reshape(size2[1])
    ydata = Z
    popt, pcov = opt.curve_fit(MNdens, xdata, ydata)
    z_fit = MNdens(xdata, *popt)
    Z_fit = z_fit.reshape(size)

    plt.subplot(1, 2, 1)
    plt.title("Real Function")
    plt.pcolormesh(X1, X2, z, norm=LogNorm(), cmap=plt.get_cmap('plasma'))
    plt.axis('equal')
    plt.colorbar()

    plt.subplot(1, 2, 2)
    plt.title("Fitted Function")
    plt.pcolormesh(X1, X2, Z_fit, norm=LogNorm(), cmap=plt.get_cmap('plasma'))
    plt.axis('equal')
    plt.colorbar()
    plt.tight_layout()

    plt.show()
    return(popt)
    
    
def v_circ_MND_func(R_kpc_data, z_kpc_data, M_tot_10Msun, R0_kpc, z0_kpc = 0.):
    a_MND_kpc, b_MND_kpc = fit_MND(R_kpc_data, z_kpc_data, _REFR0_kpc = R0_kpc)
    denom = (R0_kpc**2 + (a_MND_kpc + np.sqrt(z0_kpc**2 + b_MND_kpc**2))**2)**(3./2.)
    v_circ = R0_kpc * np.sqrt(43.01e3* M_tot_10Msun / denom)
    return(a_MND_kpc, b_MND_kpc, v_circ)

def v_circ_MND_ab(R_kpc, z_kpc, a_MND_kpc, b_MND_kpc, M_tot_10Msun):
    denom = (R_kpc**2 + (a_MND_kpc + np.sqrt(z_kpc**2 + b_MND_kpc**2))**2)**(3./2.)
    v_circ = R_kpc * np.sqrt(43.01e3* M_tot_10Msun / denom)
    return(v_circ)

def v_circ_MND_dens_func(R_kpc, z_kpc, dR_kpc, dz_kpc, M_tot_disk_stars_10Msun, M_diskstars_10Msun, R0_kpc, z0_kpc):
    a_MND_kpc, b_MND_kpc = fit_dens_MND(R_kpc, z_kpc, dR_kpc, dz_kpc, M_tot_disk_stars_10Msun, M_diskstars_10Msun)
    denom = (R0_kpc**2 + (a_MND_kpc + np.sqrt(z0_kpc**2 + b_MND_kpc**2))**2)**(3./2.)
    v_circ = R0_kpc * np.sqrt(43.01e3* M_tot_disk_stars_10Msun / denom)
    return(a_MND_kpc, b_MND_kpc, v_circ)

def MND(R_kpc, z_kpc, dR_kpc, dz_kpc, M_tot_disk_stars_10Msun, M_diskstars_10Msun, R0_kpc, z0_kpc = 0.):
    print('Start MND fit at', datetime.datetime.now().time())
    a_MND_kpc, b_MND_kpc, v_circ = v_circ_MND_dens_func(R_kpc, z_kpc, dR_kpc, dz_kpc, M_tot_disk_stars_10Msun, M_diskstars_10Msun, R0_kpc, z0_kpc = 0.)
    print('MND: a[kpc], b[kpc], vcirc [km/s]:', a_MND_kpc, b_MND_kpc, v_circ)
    return(a_MND_kpc, b_MND_kpc, v_circ)

# %%
### fit bulge

def rho_data(M_stars_10Msun, r_kpc, dr_kpc, log = True):
    
    rmin_kpc, rmax_kpc = np.min(r_kpc), np.max(r_kpc)

    rbins_kpc = np.arange(rmin_kpc, rmax_kpc, dr_kpc)
    rbins_log_kpc = np.logspace(np.log10(rmin_kpc), np.log10(rmax_kpc), 97)
    mbins_10Msun = np.zeros(len(rbins_kpc))
    volbins_kpc3 = np.zeros(len(rbins_kpc))
    if log == False:
        for i in range(len(rbins_kpc)):
            inbin = (rbins_kpc[i] <= r_kpc) & (r_kpc < (rbins_kpc[i] + dr_kpc)) # spherical shells
            mbins_10Msun[i] = np.sum(M_stars_10Msun[inbin])
            volbins_kpc3[i] = 4./3. * np.pi * dr_kpc * (3. * rbins_kpc[i]**2 + 3. * rbins_kpc[i] * dr_kpc + dr_kpc**2)
    elif log == True:
        mbins_10Msun = np.zeros(len(rbins_log_kpc))
        volbins_kpc3 = np.zeros(len(rbins_log_kpc))
        dr_log_kpc = np.log(rbins_log_kpc[1]/rbins_log_kpc[0])
        for i in range(len(rbins_log_kpc)):
            inbin = (rbins_log_kpc[i] <= r_kpc) & (r_kpc < (rbins_log_kpc[i] + dr_log_kpc)) # spherical shells
            mbins_10Msun[i] = np.sum(M_stars_10Msun[inbin])
            volbins_kpc3[i] = 4./3. * np.pi * dr_log_kpc * (3. * rbins_log_kpc[i]**2 + 3. * rbins_log_kpc[i] * dr_log_kpc + dr_log_kpc**2)

        
    rho_10Msun_kpc3 = mbins_10Msun / volbins_kpc3
    return(rho_10Msun_kpc3, rbins_log_kpc)

'''
def HB(v0_kms, a_HB_kpc, r_kpc, z_kpc, _REFR0_kpc, normalize = True):
    HB = HernquistPotential(a_HB_kpc, normalize=normalize)
    rho_model_galpy = evaluateDensities(HB, r_kpc, z_kpc) 
    rho_model_10Msun_kpc3 = rho_model_galpy * bovy_conversion.dens_in_msolpc3(v0_kms, _REFR0_kpc) * 10.
    return(rho_model_10Msun_kpc3)
'''


def Hernquistdens(r_kpc, a_HB_kpc, amp_10Msun):
    rho_10Msun_kpc3 = amp_10Msun / (4. * np.pi * a_HB_kpc**3.) * (1. / ((r_kpc / a_HB_kpc) * (1. + r_kpc / a_HB_kpc)**3))
    return(np.log(rho_10Msun_kpc3))
    
def fit_HB(M_stars_10Msun, r_kpc, dr_kpc):
    rho_data_10Msun_kpc3, rbins_kpc = rho_data(M_stars_10Msun, r_kpc, dr_kpc)
    #print(rbins_kpc)
    rho_data_10Msun_kpc3 = np.log(rho_data_10Msun_kpc3)
    plt.plot(rbins_kpc, rho_data_10Msun_kpc3, 'r.')
    plt.xlabel('r[kpc]')
    plt.ylabel('rho [10^10Msun/kpc^3]')
    #print(rho_data_10Msun_kpc3, rbins_kpc)
    #print(rho_data_10Msun_kpc3)
    rho_data_10Msun_kpc3 = np.where(np.isinf(rho_data_10Msun_kpc3), rho_data_10Msun_kpc3[-2] ,rho_data_10Msun_kpc3)
    #print(rho_data_10Msun_kpc3)
    popt, pcov = opt.curve_fit(Hernquistdens, rbins_kpc, rho_data_10Msun_kpc3)
    a_HB_kpc = popt[0]
    plt.plot(rbins_kpc, Hernquistdens(rbins_kpc, popt[0], popt[1]))
    plt.show()
    return(a_HB_kpc)

def v_circ_HB_func(M_stars_10Msun, r_kpc, dr_kpc, r0_kpc):
    a_HB_kpc = fit_HB(M_stars_10Msun, r_kpc, dr_kpc)
    M_tot_10Msun = np.sum(M_stars_10Msun)
    vcirc = np.sqrt(43.01e3* M_tot_10Msun * r0_kpc)/ (r0_kpc + a_HB_kpc)
    #vcirc = np.sqrt(43.01e3 * M_enc / r_kpc)
    return(a_HB_kpc, vcirc)

def v_circ_HB_func_justr(r_kpc, a_HB_kpc, M_tot_10Msun):
    vcirc = np.sqrt(43.01e3* M_tot_10Msun * r_kpc)/ (r_kpc + a_HB_kpc)
    return(vcirc)
    
def v_circ_HB_a(r_kpc_spher, M_spher_10Msun):#, a_HB_kpc, M_stars_10Msun):
    """
    INPUT:
    """
    #M_tot_10Msun = np.sum(M_stars_10Msun)
    #vcirc = np.sqrt(43.01e3* M_tot_10Msun * r_kpc)/ (r_kpc + a_HB_kpc)

    r_kpc = np.linspace(np.min(r_kpc_spher), np.max(r_kpc_spher), 25)
    v_circ_shell = np.zeros(len(r_kpc))
    for i, item in enumerate(r_kpc):
        mass_mask = np.where((r_kpc_spher<=item))
        mass_10Msun  = np.sum(M_spher_10Msun[mass_mask])
        v_circ_shell[i] = np.sqrt(43.01e3 * mass_10Msun / item)
    return(v_circ_shell)

def HB(M_stars_10Msun, r_kpc, dr_kpc, r0_kpc):
    print('Start HB fit at', datetime.datetime.now().time())
    a_HB_kpc, vcirc = v_circ_HB_func(M_stars_10Msun, r_kpc, dr_kpc, r0_kpc)
    print('HB: a[kpc], vcirc [km/s]:', a_HB_kpc, vcirc)
    return(a_HB_kpc, vcirc)

def HB2(r_kpc_spher, M_spher_10Msun):
    vcirc = v_circ_HB_a(r_kpc_spher, M_spher_10Msun)
    return(vcirc)

# %% [markdown]
# $v_{circ_{tot}} = \sqrt{\frac{GM(<R_0)}{R_0}} $
#
# $G = 43.0071 \cdot 10^{3} \frac{kpc}{10^{10} M_\odot}\frac{km^2}{s^2}$

# %%
def v_circ_tot_func(r_kpc):
    try:
        test = len(r_kpc)
        types = ( s.type == 0) + (s.type == 1) + (s.type == 2) + (s.type == 3) + (s.type == 4)

        #mass_mask    = np.zeros(len(r_kpc))
        #mass_10Msun  = np.zeros(len(r_kpc))
        v_circ_shell = np.zeros(len(r_kpc))

        for i, item in enumerate(r_kpc):
            mass_mask    = np.where( (types) & (s.halo == 0) & ((1000. * s.r()) < (item)))
            mass_10Msun  = np.sum(s.mass[mass_mask])
            v_circ_shell[i] = np.sqrt(43.01e3 * mass_10Msun / item)

        v_circ =  v_circ_shell
    except:
        mass_10Msun = np.sum(s.mass[((1000. * s.r()) <= r_kpc) ] )
        v_circ = np.sqrt(43.01e3 * mass_10Msun / r_kpc)
        
    return(v_circ)

# %%
### fit halo (variably)

def v_circ_NFW_func(r_kpc, v_circ_MND, v_circ_HB, v_circ_tot = None):
    try:
        if v_circ_tot == None:
            v_circ_tot = v_circ_tot_func(r_kpc)
    except ValueError:
        pass
        #continue

    v_circ_NFW = np.sqrt(v_circ_tot**2 - v_circ_MND**2 - v_circ_HB**2) #could be negative! then its nan vals
    return(v_circ_NFW)

# %%
#_____function that sets-up galpy potential_____
def setup_galpy_potential(a_MND_kpc, b_MND_kpc, a_NFWH_kpc, a_HB_kpc, n_MND, n_NFWH, n_HB, _REFR0_kpc):
    
    #test input:
    if (a_MND_kpc <= 0.) or (b_MND_kpc <= 0.) or (a_NFWH_kpc <= 0.) or (a_HB_kpc <= 0.) \
       or (n_MND <= 0.) or (n_NFWH <= 0.) or (n_HB <= 0.) or (n_MND >= 1.) or (n_NFWH >= 1.) or (n_HB >= 1.):
        raise ValueError('Error in setup_galpy_potential: '+\
                         'The input parameters for the scaling profiles do not correspond to a physical potential.')
    if np.fabs(n_MND + n_NFWH + n_HB - 1.) > 1e-7:
        raise ValueError('Error in setup_galpy_potential: '+\
                         'The sum of the normalization does not add up to 1.')
        
    #trafo to galpy units:
    a_MND  = a_MND_kpc  / _REFR0_kpc
    b_MND  = b_MND_kpc  / _REFR0_kpc
    a_NFWH = a_NFWH_kpc / _REFR0_kpc
    a_HB   = a_HB_kpc   / _REFR0_kpc
    
    #setup potential:
    disk = MiyamotoNagaiPotential(
                a = a_MND,
                b = b_MND,
                normalize = n_MND)
    halo = NFWPotential(
                a = a_NFWH,
                normalize = n_NFWH)
    bulge = HernquistPotential(
                a = a_HB,
                normalize = n_HB) 
     
    return [disk,halo,bulge]

# %%
#_____function for scipy.differential_evolution that sums the relative error squares_____
def rel_pot_error_scipydifferentialevolution(x,*args):
    
    # read fitting parameters:
    v0_tot_kms = x[0]
    a_NFWH_kpc = x[1]
        
    
    # read data:
    
    a_MND_kpc     = args[0]
    b_MND_kpc     = args[1]
    a_HB_kpc      = args[2]    
    v0_MND_kms    = args[3]
    v0_HB_kms     = args[4]
    R_kpc_data    = args[5]
    z_kpc_data    = args[6]
    pot_kms2_data = args[7]
    _REFR0_kpc    = args[8]
    
    
    v0_NFWH_kms = np.sqrt(v0_tot_kms**2 - v0_HB_kms**2 - v0_MND_kms**2)
    
    n_NFWH = v0_NFWH_kms**2 / v0_tot_kms**2
    n_HB   = v0_HB_kms**2   / v0_tot_kms**2
    n_MND  = v0_MND_kms**2  / v0_tot_kms**2
    # setup potential (and check if parameters are physical):
    try:
        pot_galpy_model = setup_galpy_potential(a_MND_kpc, b_MND_kpc, a_NFWH_kpc, a_HB_kpc, n_MND, n_NFWH, n_HB, _REFR0_kpc)
    except Exception as e:
        return np.inf

    # calculate potential values at (R,z) for this potential:
    #print(R_kpc_data)
    #print(z_kpc_data)
    #print(_REFR0_kpc)
    #print(v0_tot_kms)
    pot_kms2_model = evaluatePotentials(pot_galpy_model,
                                   R_kpc_data / _REFR0_kpc,
                                   z_kpc_data / _REFR0_kpc) * (v0_tot_kms)**2
    
    #calculate sum of relative error squares:
    err = np.sum(((pot_kms2_data - pot_kms2_model) / pot_kms2_model)**2)
    return err

# %%
### get everything together somehow 

level = 4
startsnap = 60
endsnap = 128

#j = 0

for halo_number in [24]:  # range(1, 31):
    halodir = basedir+"halo_{0}/".format(halo_number)
    snappath = halodir+"output/"
    for snapnr in range(startsnap,endsnap,1):
        print("snapnr  : {0}".format(snapnr))
        print(datetime.datetime.now().time())
        try:
            s, sf = eat_snap_and_fof(level, halo_number, snapnr, snappath, loadonlytype=[1,2,3,4], 
            haloid=0, galradfac=0.1, verbose=True)    
        except KeyError:
            print('\n\n', snapnr, 'not read in.\n\n')
            continue
            
        try: 
            # Clean negative and zero values of gmet to avoid RuntimeErrors
            # later on (e.g. dividing by zero)
            s.data['gmet'] = np.maximum( s.data['gmet'], 1e-40 )
        except:
            continue

            
        
        R0_kpc = 1000. * 1./3. * s.galrad
        z0_kpc = 0.
        r0_kpc = R0_kpc
        dr_kpc = 0.5
        
        disk_ID, spheroid_ID, bulge_ID, halo_ID = decomp(s, r_cutoff_Mpc = 0.05, Gcosmo = 43.01, plotter = True, disccirc_min = 0.7, disccirc_max = 1.7)
        
        ## get data from simulations

        i_stars = np.where( (s.halo == 0) & (s.type == 4) & (s.r() <= s.galrad) & (s.r() > 0.) )
        #j = np.where( s.data[i_stars]['age'] > 0. )
        #i_stars = i_stars[j]
        i_spheroid = np.isin(s.id, spheroid_ID)
        i_disk = np.isin(s.id, disk_ID)
        i_dm = np.where( (s.halo == 0) & ((s.type == 1) + (s.type == 2) + (s.type == 3)) )
        
        galrad_kpc = 1000. * s.galrad
        
        # choice of R_kpc_data and z_kpc_data
        (x_kpc, y_kpc, z_kpc), (vx_kpc, vy_kpc, vz_kpc), rxyz_kpc, rxy_kpc = get_cartesian_vectors(s, sf, i_stars)
        (R_kpc, phi, z_kpc), (vR_kms, vphi_kms, vz_kms) = get_cylindrical_vectors(s, sf, i_stars)
        #print('istars', len(i_stars[0]), 'idisk', np.sum(i_disk), 'i_spher', np.sum(i_spheroid))

        (x_kpc_disk, y_kpc_disk, z_kpc_disk), (vx_kpc_disk, vy_kpc_disk, vz_kpc_disk), rxyz_kpc_disk, rxy_kpc_disk = get_cartesian_vectors(s, sf, i_disk)
        (R_kpc_disk, phi_disk, z_kpc_disk), (vR_kms_disk, vphi_kms_disk, vz_kms_disk) = get_cylindrical_vectors(s, sf, i_disk)
        
        (x_kpc_spher, y_kpc_spher, z_kpc_spher), (vx_kpc_spher, vy_kpc_spher, vz_kpc_spher), rxyz_kpc_spher, rxy_kpc_spher = get_cartesian_vectors(s, sf, i_spheroid)
        (R_kpc_spher, phi_spher, z_kpc_spher), (vR_kms_spher, vphi_kms_spher, vz_kms_spher) = get_cylindrical_vectors(s, sf, i_spheroid)

        
        #R_kpc_data = R_kpc[i_disk][i_stars]
        #z_kpc_data = z_kpc[i_disk][i_stars]
        r_kpc_spher = 1000. * s.r()[i_spheroid]
        #print(np.max(r_kpc))
        
        plt.hist2d(R_kpc_disk, z_kpc_disk, 41, norm=LogNorm())
        plt.colorbar()
        plt.axis('equal')
        plt.show()
        plt.hist2d(x_kpc_disk, y_kpc_disk, 41, norm=LogNorm())
        plt.axis('equal')
        plt.colorbar()
        plt.show()        
        
        plt.hist2d(R_kpc_spher, z_kpc_spher, 41, norm=LogNorm())
        plt.axis('equal')
        plt.colorbar()
        plt.show()
        plt.hist2d(x_kpc_spher, y_kpc_spher, 41, norm=LogNorm())
        plt.axis('equal')
        plt.colorbar()
        plt.show()
        
        M_disk_10Msun = s.mass[i_disk]
        M_disk_tot_10Msun = np.sum(s.mass[i_disk])
        M_spher_10Msun = s.mass[i_spheroid]
        
        r_kpc_binned = np.linspace(np.min(r_kpc_spher), np.max(r_kpc_spher), 25)
        #print(r_kpc_binned)
        
        ## fit single parts
        res1 = MND(R_kpc_disk, z_kpc_disk, dR_kpc = 0.5, dz_kpc = 1., M_tot_disk_stars_10Msun = M_disk_tot_10Msun, M_diskstars_10Msun = M_disk_10Msun, R0_kpc = R0_kpc, z0_kpc = 0.)
        a_MND_kpc, b_MND_kpc, v_circ_MND = res1
        res = fit_dens_MND(R_kpc_disk, z_kpc_disk, dR_kpc = 0.5, dz_kpc = 1., M_tot_disk_stars_10Msun = M_disk_tot_10Msun, M_diskstars_10Msun = M_disk_10Msun)
        #a_MND_kpc, b_MND_kpc, v_circ_MND = MND(R_kpc_data[i_disk], z_kpc_data[i_disk], M_stars_tot_10Msun, R0_kpc, z0_kpc = 0.)
        a_HB_kpc, v_circ_HB = HB(M_spher_10Msun, r_kpc_spher, dr_kpc, r0_kpc)
        v_circ_test1 = HB2(r_kpc_spher, M_spher_10Msun)
        v_circ_test2 = v_circ_HB_func_justr(r_kpc_binned, a_HB_kpc, np.sum(M_spher_10Msun))
        
        plt.plot(r_kpc_binned, v_circ_test1, 'r-', label = '$\sqrt{\\frac{GM(<r)}{r}}$')
        plt.plot(r_kpc_binned, v_circ_test2, 'g--', label = '$\\frac{\sqrt{GMr}}{r+a}$')
        plt.legend()
        plt.show()
        #rot curves
        
        
        #### GUESS OK WITH THE SPHEROID AND DISK FIT 
        
        r_kpc           = np.linspace(0, 1000. * s.galrad, 100)
        v_circ_disk     = v_circ_MND_ab(R_kpc=r_kpc, z_kpc=0., a_MND_kpc=a_MND_kpc, b_MND_kpc=b_MND_kpc, M_tot_10Msun=M_disk_tot_10Msun)
        v_circ_spheroid = v_circ_HB_func_justr(r_kpc, a_HB_kpc, np.sum(M_spher_10Msun))
        v_circ_tot      = v_circ_tot_func(r_kpc=r_kpc)
        v_circ_halo     = v_circ_NFW_func(r_kpc, v_circ_disk, v_circ_spheroid, v_circ_tot)

        v0_MND_kms = v_circ_MND_ab(R0_kpc, z0_kpc, a_MND_kpc=a_MND_kpc, b_MND_kpc=b_MND_kpc, M_tot_10Msun=M_disk_tot_10Msun)
        v0_HB_kms  = v_circ_HB_func_justr(R0_kpc, a_HB_kpc, np.sum(M_spher_10Msun))
        print(v0_MND_kms, v0_HB_kms)
        v0_circ_tot = v_circ_tot_func(r_kpc=R0_kpc)
        print('v0_circ_tot =', v0_circ_tot)
        
        plt.plot(r_kpc, v_circ_spheroid, 'b:', label = 'spheroid')
        plt.plot(r_kpc, v_circ_disk, 'g-.', label = 'disk')
        plt.plot(r_kpc, v_circ_halo, 'r--', label = 'halo')
        plt.plot(r_kpc, v_circ_tot, 'k-', label = 'total')
        plt.xlabel('R [kpc]')
        plt.ylabel('$v_{circ} \ [km/s]$')
        plt.legend()        
        plt.show()
        # calculate v_circ NFW
        #v_circ_NFW = v_circ_NFW_func(v_circ_MND, v_circ_HB, R0_kpc)
        #print(v_circ_NFW, v_circ_MND, v_circ_HB)
        #nn = 35
        #R0_ref = r_kpc[nn]
        #print(R0_ref)
        #v0_ref = v_circ_tot[nn]
        #n_NFW  = v_circ_halo[nn]** 2      / v_circ_tot[nn] **2
        #n_HB   = v_circ_spheroid[nn] ** 2 / v_circ_tot[nn] **2
        #n_MND  = v_circ_disk[nn] ** 2     / v_circ_tot[nn] **2
        #print(r_kpc[30], n_NFW + n_HB + n_MND )
        
        part_num = 50001
        
        i_dm, = np.where( (s.halo == 0) & (s.r() < s.galrad) & (s.r() > 0.) & ((s.type == 1) + (s.type == 2) + (s.type == 3) ))


        r_kpc_dm = 1000. * s.r()[i_dm]
        (R_kpc_dm, phi_rad_dm, z_kpc_dm), (vR_kms_dm, vphi_kms_dm, vz_kms_dm) = get_cylindrical_vectors(s, sf, i_dm) 
        pot_kms2_dm = s.pot[i_dm]

        # draw random sample out of data
        try:
            rand_samp = np.array(random.sample(list(enumerate(pot_kms2_dm)), part_num))
            rand_ind = rand_samp[:,0].astype(int)
            pot_kms2_dm_data = rand_samp[:, 1]
            r_kpc_dm_data = r_kpc_dm[rand_ind]
            R_kpc_dm_data = R_kpc_dm[rand_ind]
            z_kpc_dm_data = z_kpc_dm[rand_ind]
        except ValueError:        
            pot_kms2_dm_data = pot_kms2_dm
            r_kpc_dm_data = r_kpc_dm
            R_kpc_dm_data = R_kpc_dm
            z_kpc_dm_data = z_kpc_dm
        lower_floor = 1e-3
        bounds = ((5./6. * v0_circ_tot, 400.), #REF_V0_kms
                 (lower_floor, 400.)) #a_NFWH
        args = (a_MND_kpc, b_MND_kpc, a_HB_kpc, v0_MND_kms, v0_HB_kms, R_kpc_dm_data, z_kpc_dm_data, pot_kms2_dm_data, R0_kpc)

        print(args)
        plt.hist2d(R_kpc_dm_data, z_kpc_dm_data, 21, norm=LogNorm())
        plt.axis('equal')
        plt.colorbar()
        plt.show()
        #plt.hist2d(x_kpc_spher, y_kpc_spher, 21, norm=LogNorm())
        #plt.axis('equal')
        #plt.colorbar()
        #plt.show()

        #fitting:
        res = opt.differential_evolution(
                    rel_pot_error_scipydifferentialevolution,
                    bounds=bounds,
                    args=args,#, MND, HB, NFWH),
                    strategy='best1bin',
                    maxiter=1000,tol=0.01,atol=1e-7,
                    disp=False
                    )
        

        v0_kms_bestfit     = res.x[0]
        a_NFWH_kpc_bestfit = res.x[1]
    
        
        v0_NFWH_kms = np.sqrt(v0_kms_bestfit**2 - v0_HB_kms**2 - v0_MND_kms**2)
        data_saved = np.array([snapnr, R0_kpc, v0_kms_bestfit, a_MND_kpc, b_MND_kpc, a_HB_kpc, a_NFWH_kpc_bestfit, v0_MND_kms, v0_HB_kms, v0_NFWH_kms])
        print(len(data_saved), np.shape(data_saved))
        print(data_saved)
        formt = '%3.12f'
        
        np.savetxt(filedir + 'potential_params/pot_snap_' + str(snapnr), data_saved, fmt = formt)
        print('Snapshot = ', snapnr)
        print('v0_tot_kms at R0_kpc =', R0_kpc, ':', v0_kms_bestfit)
        print('Stellar Disk - a_MND_kpc =', a_MND_kpc, 'b_MND_kpc =', b_MND_kpc, 'v0_MND_kms =', v0_MND_kms)
        print('Stellar Spheroid - a_HB_kp c=', a_HB_kpc, 'v0_HB_kms =', v0_HB_kms)
        print('DM Halo - a_NFWH_kpc =', a_NFWH_kpc_bestfit, 'v0_NFWH_kms =', v0_NFWH_kms)

# %%
v0_NFWH_kms = np.sqrt(v0_kms_bestfit**2 - v0_HB_kms**2 - v0_MND_kms**2)
print('v0_tot_kms at R0_kpc =', R0_kpc, ':', v0_kms_bestfit)
print('Stellar Disk - a_MND_kpc =', a_MND_kpc, 'b_MND_kpc =', b_MND_kpc, 'v0_MND_kms =', v0_MND_kms)
print('Stellar Spheroid - a_HB_kp c=', a_HB_kpc, 'v0_HB_kms =', v0_HB_kms)
print('DM Halo - a_NFWH_kpc =', a_NFWH_kpc_bestfit, 'v0_NFWH_kms =', v0_NFWH_kms)

# %%
v0_NFWH_kms = np.sqrt(v0_kms_bestfit**2 - v0_HB_kms**2 - v0_MND_kms**2)
print('v0_tot_kms at R0_kpc =', R0_kpc, ':', v0_kms_bestfit)
print('Stellar Disk - a_MND_kpc:', a_MND_kpc, 'b_MND_kpc:', b_MND_kpc, 'v0_MND_kms:', v0_MND_kms)
print('Stellar Spheroid - a_HB_kpc:', a_HB_kpc, 'v0_HB_kms:', v0_HB_kms)
print('DM Halo - a_NFWH_kpc:', a_NFWH_kpc_bestfit, 'v0_NFWH_kms:', v0_NFWH_kms)

# %%
n_NFW = v_circ_halo[35] ** 2 / v_circ_tot[35] **2
n_HB = v_circ_spheroid[35] ** 2 / v_circ_tot[35] **2
n_MND = v_circ_disk[35] ** 2 / v_circ_tot[35] **2
print(r_kpc[65], n_NFW + n_HB + n_MND )

# %%
v_circ_NFW = v_circ_NFW_func(v_circ_MND, v_circ_HB, R0_kpc)
print(v_circ_NFW, v_circ_MND, v_circ_HB)
print(np.sqrt(v_circ_NFW**2 + v_circ_HB**2 + v_circ_MND**2))

# %%
a_HB_kpc

# %%
print(a_MND_kpc, b_MND_kpc, a_HB_kpc
     )

# %%
plt.plot(r_kpc, v_circ_spheroid, 'k.', label = 'spheroid')
plt.plot(r_kpc, v_circ_disk, 'g-', label = 'disk')
plt.plot(r_kpc, v_circ_halo, 'r--', label = 'halo')
plt.plot(r_kpc, v_circ_tot, 'b-.', label = 'total')
plt.xlabel('R [kpc]')
plt.ylabel('$v_{circ} \ [km/s]$')
plt.legend()
